# %% [markdown]
# # Assignment 1: Inspecting the Dataset

# %% [markdown]
# In this first assignment, we will get to know the dataset that we will be using throughout. You can find the assignment tasks at the bottom of this document.
#
# Our dataset consists of short texts (article abstracts) from the [PubMed](https://www.ncbi.nlm.nih.gov/pubmed/) database of scientific publications in the Life Science domain. As the full dataset consists of millions of documents, we are using just a small subset, namely all publications that contain the word "cognition" in their title or abstract. You can download that dataset in the form of four files (`cognition_Summaries.pkl.bz2`, etc.) from this Github (data folder). Save these four files in a directory called `data` (do not unpack them, but save them as .bz2 files!), which should be a sub-directory of the one that contains this notebook file.

# %% [markdown]
# ## Importing some Libraries

# %%
from collections import namedtuple, defaultdict, Counter
import pickle, bz2

# %% [markdown]
# ## Loading the Dataset

# %%
Summaries_file = 'data/cognition_Summaries.pkl.bz2'
Summaries = pickle.load( bz2.BZ2File( Summaries_file, 'rb' ) )

# %% [markdown]
# To make it easier to access the data, we convert here paper entries into [named tuples](http://docs.python.org/3/library/collections.html#collections.namedtuple). This will allow us to refer to fields by keyword (like `var.year`), rather than index (like `var[2]`).

# %%
paper = namedtuple( 'paper', ['title', 'authors', 'year', 'doi'] )

for (id, paper_info) in Summaries.items():
    Summaries[id] = paper( *paper_info )

# %%
Summaries[36220089]
# Out:
# paper(title='Pollinator cognition: Framing bee memories in\xa0an\xa0ecological context.', authors=['Giurfa M'], year=2022, doi='10.1016/j.cub.2022.08.043')

# %%
Summaries[36220089].title
# Out:
# 'Pollinator cognition: Framing bee memories in\xa0an\xa0ecological context.'

# %% [markdown]
# ## Dataset Statistics

# %% [markdown]
# The two lines below will install [matplotlib](http://matplotlib.org/) and [NumPy](http://www.numpy.org/), if they are not installed already (if that doesn't work, you might have to download and install them from [here](http://matplotlib.org/downloads.html) and [here](http://sourceforge.net/projects/numpy/files/NumPy/1.10.1/)). We will need these libraries for drawing diagrams and analyzing the data below.

# %%
! pip install --user matplotlib
! pip install --user numpy
# Out:
# Requirement already satisfied: matplotlib in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.17 in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: six>=1.5 in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /Users/riles/opt/anaconda3/lib/python3.9/site-packages (1.21.5)

# %%
import matplotlib.pyplot as plt

# show plots inline within the notebook
# %matplotlib inline
# set plots' resolution
plt.rcParams['savefig.dpi'] = 100

# %% [markdown]
# ### Papers per Year

# %% [markdown]
# First, we will try to find out how many papers in the dataset were published per year. We are using the [Counter](https://docs.python.org/3/library/collections.html#collections.Counter) class for this.

# %%
paper_years = [ p.year for p in Summaries.values() ]
papers_per_year = sorted( Counter(paper_years).items() )

print('Number of papers in the dataset per year for the past decade:')
print(papers_per_year[-10:])
# Out:
# Number of papers in the dataset per year for the past decade:
# [(2014, 5455), (2015, 6000), (2016, 6494), (2017, 7049), (2018, 7431), (2019, 7920), (2020, 8757), (2021, 10568), (2022, 9781), (2023, 10)]

# %% [markdown]
# Filtering results, to obain only papers since 1940:

# %%
papers_per_year_since_1940 = [ (y,count) for (y,count) in papers_per_year if y >= 1940 ]
years_since_1940 = [ y for (y,count) in papers_per_year_since_1940 ]
nr_papers_since_1940 = [ count for (y,count) in papers_per_year_since_1940 ]

print('Number of papers in the dataset published since 1940:')
print(sum(nr_papers_since_1940))
# Out:
# Number of papers in the dataset published since 1940:
# 102110

# %% [markdown]
# Creating a bar plot to visualize the results (using [matplotlib.pyplot.bar](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.bar)):

# %%
plt.bar(x=years_since_1940, height=nr_papers_since_1940, width=1.0)
plt.xlim(1940, 2021)
plt.xlabel('year')
plt.ylabel('number of papers');

# %% [markdown]
# Alternatively, we can get the same result by plotting it as a histogram with [matplotlib.pyplot.hist](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist):

# %%
plt.hist( x=[p.year for p in Summaries.values()], bins=range(1940,2023) );
plt.xlim(1940, 2022)
plt.xlabel('year')
plt.ylabel('number of papers');

# %% [markdown]
# ### Papers per Author

# %% [markdown]
# Here, we will obtain the distribution characterizing the number of papers published by an author.

# %%
# flattening the list of lists of authors:
flat_author_list = [ auth for paper in Summaries.values() for auth in paper.authors ]

nr_papers_by_author = Counter( flat_author_list )

# %%
print('Number of authors in the dataset with distinct names:')
print(len(nr_papers_by_author))
# Out:
# Number of authors in the dataset with distinct names:
# 232358

# %%
print('Top 50 authors with greatest number of papers:')
print(sorted(nr_papers_by_author.items(), key=lambda i:i[1], reverse=True)[:50])
# Out:
# Top 50 authors with greatest number of papers:
# [('Wang Y', 661), ('Zhang Y', 580), ('Wang J', 523), ('Li Y', 485), ('Zhang J', 441), ('Wang X', 434), ('Liu Y', 392), ('Li X', 370), ('Zhang X', 368), ('Wang L', 347), ('Bennett DA', 345), ('Chen Y', 341), ('Zhang L', 318), ('Li J', 313), ('Liu X', 292), ('Liu J', 288), ('Wang H', 284), ('Wang Z', 279), ('Chen J', 274), ('Li H', 272), ('Chen X', 268), ('Zhang Z', 246), ('Zhang H', 240), ('Yang Y', 234), ('Zhang W', 218), ('Wang C', 218), ('Xu Y', 217), ('Wang S', 203), ('Alzheimer’s Disease Neuroimaging Initiative.', 202), ('Li Z', 199), ('Lee J', 199), ('Li S', 198), ('Yaffe K', 194), ('Harvey PD', 192), ('Yang J', 184), ('Li C', 184), ('Li W', 183), ('Li L', 181), ('Wang Q', 176), ('Wang W', 176), ('Chen L', 174), ('Zhou Y', 174), ('Chen H', 173), ('Wu Y', 173), ('Chen C', 172), ('Wilson RS', 172), ("Alzheimer's Disease Neuroimaging Initiative.", 170), ('Zhang M', 170), ('Xu X', 167), ('Li M', 166)]

# %% [markdown]
# Then we can create a histogram to visualize the results:

# %%
plt.hist( x=list(nr_papers_by_author.values()), bins=range(101), log=True )
plt.xlabel('number of papers authored')
plt.ylabel('number of authors');

# %% [markdown]
# ### Authors per Paper

# %% [markdown]
# Then we can make a similar analysis for the number of authors per paper:

# %%
plt.hist(x=[ len(p.authors) for p in Summaries.values() ], bins=range(20), align='left', density=True)
plt.xlabel('number of authors in one paper')
plt.ylabel('fraction of papers')
plt.xlim(-0.5, 15.5);

# %% [markdown]
# ### Words in Titles

# %% [markdown]
# And then we can have a first look into the words we find in titles (applying a very naive word splitting method for now):

# %%
words = [ word.lower() for paper in Summaries.values() for word in paper.title.split(' ') ]
word_counts = Counter(words)


print('Number of distinct words in the paper titles:')
print(len(word_counts))
# Out:
# Number of distinct words in the paper titles:
# 75212

# %% [markdown]
# ----------

# %% [markdown]
# # Tasks

# %% [markdown]
# **Name: Riley Crahen**

# %% [markdown]
# ### Task 1
#
# Create a Python dictionary object that returns a set of all names of first authors (that is, the authors that appear first in the list of authors) for a given year. Name this dictionary `first_authors_at_year`. (You can use a [*defaultdict*](https://docs.python.org/3/library/collections.html#collections.defaultdict) with a default value of [*set*](https://docs.python.org/3/library/stdtypes.html#set-types-set-frozenset).) Demonstrate the working of this dictionary by showing the set of first authors for the year 1970.

# %%
from collections import defaultdict


# key is year
# value is set of authors
first_authors_at_year = defaultdict(set)
for paper in Summaries.values():
    if(len(paper.authors)>0):
        first_authors_at_year[paper.year].add(paper.authors[0])

# print out all first authors for year > 1970
for year, authors in first_authors_at_year.items():
    if(year > 1970):
        print(str(year) + ": " + str(authors) + "\n\n")
# Out:
# 2022: {'Minson JA', 'Stekic A', 'Jacobson SL', 'Hauschildt M', 'Cui F', 'Jacobs HIL', 'Moura BM', 'Shaaban CE', 'Galera H', 'Patel A', 'Yao S', 'Goetz SMM', 'Carlos AF', 'Terenzi D', 'Eum S', 'Borghesani V', 'Xu M', 'Kirolos A', 'He X', 'Bisagno E', 'Ng TP', 'Abu-Akel A', 'Chen YC', 'Kondoh H', 'Rose JP', 'Desebrock C', 'Qiu A', 'Saneto RP', 'Gryfe P', 'de Wit H', 'Anderson EM', 'Mahmassani HA', 'Salmani H', 'Chien YL', 'Salavati S', 'Deane G', 'Tracy GC', 'Koren Y', 'Noel JA', 'Growney CM', 'Kozlovsky DY', 'Higashi T', 'Roell L', 'Wenger MJ', 'Kojima H', 'Xi Y', 'Aiello EN', 'Stephenson K', 'Wise TB', 'Modi N', 'Jain S', 'Sizemore BA', 'Kohansal F', 'Glasman P', 'Sood M', 'Heo CM', 'Kovac V', 'Lier EJ', 'Repple J', 'Roberts AI', 'Rhodes S', 'Shen J', 'Améndola L', 'Merchant AT', 'Heck IA', 'Guan CQ', 'Halayem S', 'Minor M', 'Moreno GL', 'Cox MF', 'Dickey CW', 'Lal P', 'Bitanihirwe BKY', 'Mueller FS', 'Mana J', 'Wen K', 'Ursino M', 'Marent PJ', 'Khera T', 'Liljenström H', 'Cogliati Dezza I', 'Chung-Fat-Yim A', 'Leichtmann B', 'Burgess PW', 'Orum MH', 'Xiang L', 'Ameen F', 'Sarubbo F', 'Stengel C', 'Hamerschmidt R', 'Harrison BJ', 'Fiabane E', 'Navarro E', 'Hasan SM', 'Rodrigues FM', 'Frost NJ', 'Chen CLH', 'Dong C', 'Haman M', 'Tchalla A', 'Botero-Rodríguez F', 'Zieneldien T', 'Yan Q', 'Bulevich JB', 'Cramer RJ', 'Zhong L', 'Lempriere S', 'Snowden JS', 'Song W', 'Chen X', 'Leisman G', 'Koole SL', 'Cortes HM', 'Sigala N', 'Holthaus TA', 'Felín MS', 'Mick S', 'Meinow B', 'Levine DA', 'Sandsten KE', 'Bouter Y', 'Arai H', 'Srikulnath K', 'Schäfer JL', 'Genov K', 'Lee KM', 'Ronold EH', 'Harkin D', 'Pedroso RV', 'Yeh WH', 'Bray CE', 'Guo JR', 'Bara I', 'Kuhnke P', 'Xiao Y', 'De Giorgi R', 'Lindbergh CA', 'Lany J', 'Anita NZ', 'Saldana SL', 'Sideli L', 'Smeds H', 'Day E', 'Flemming DJ', 'Liu L', 'Sanchez-Lara E', 'Dorfer C', 'Abu-El-Rub E', 'Del Corral T', 'Smith JA', 'Soares JS', 'Abd-Alrazaq A', 'Jin SV', 'Zhou A', 'Maule J', 'Wieck C', 'Arji G', 'Llana T', 'Enfield NJ', 'Apple AC', 'Perrykkad K', 'Temprado JJ', 'Mustra Rakic J', 'Kim HH', 'Stocks J', 'Antonucci LA', 'Ke Z', 'Khandekar P', 'Tubbs AS', 'Sugimoto T', 'Anunciado-Koza RP', 'Sylvers DL', 'Lavi-Rotbain O', 'Walt L', 'Kay KR', 'Pabst A', 'Bohn M', 'Semendric I', 'Denissen S', 'He K', 'Hong WF', 'Vernon SD', 'Fairfield B', 'Luccarelli J', 'Khanna A', 'Yuan Y', 'Yon D', 'Giszas V', 'Vaskinn A', 'Nishiomasu K', 'Hoy N', 'Wisén N', 'Nobre JNP', 'Park KM', 'Monteiro-Junior RS', 'Völter C', 'Caldinelli C', 'Blackwood J', 'Rosenberg A', 'Lichtenberg PA', 'Cao B', 'Mureșanu IA', 'Ramdin TD', 'Yamamoto K', 'High RA', 'Fang M', 'Hunter P', 'Vacca M', 'Huang WY', 'Araya C', 'Bailey M', 'Isbilen ES', 'Bellens A', 'Brubaker L', 'Pardo G', 'Hammershøj LG', 'Cole ER', 'Brookshire G', 'Withey SL', 'Qu N', 'Marullo S', 'Kimmel HJ', 'Dabin R', 'Greimel S', 'Huang H', 'Kim BC', 'Bland AR', 'Beaton D', 'Premachandra B', 'Çavdar S', 'Ryan JD', 'Fusi G', 'Ambegaonkar JP', 'Lau J', 'Buvarp D', 'Horchak OV', 'Ma S', 'Rodríguez Villar AJ', 'Weinstock Z', 'Cloppenborg T', 'Gami-Patel P', 'Kim SH', 'Bell TR', 'Gupta A', 'Hengstschläger A', 'Park G', 'Alsanie WF', 'Woods MJ', 'Snellman A', 'McDonald JB', 'Smith R', 'Sezer O', 'Calderón-Garcidueñas L', 'Aguilar Ramirez DE', 'Del Castillo A', 'Kim GW', 'Yuan F', 'Li AR', 'Hong KS', 'Luque-Suarez A', 'Fang F', 'Qiao P', 'Barranco A', 'Brugada-Ramentol V', 'Charvet CJ', 'Bosnes I', 'Boeve BF', 'Zhou S', 'Schneider LS', 'Sperry SH', 'Gordon R', 'Engen MJ', 'Watanabe S', 'Liu Q', 'Cabanas-Valdés R', 'Kautiainen RJ', 'Lozupone M', 'Locquet M', 'Ferretjans R', 'Peak JM', 'Liu CC', 'Haefliger R', 'Kaczyńska J', 'Muthui R', 'Bonberg N', 'Steffener J', 'Lengel D', 'Kumar D', 'Lima CNC', 'Andersen RA', 'Meng D', 'Makecha RN', 'Chaput M', 'Shuman CJ', 'Ross TW', 'Madhusudhan U', 'Adamowicz DH', 'Clayden JD', 'Haskins AJ', 'Dumuid D', 'Nelson PT', 'Palamarchuk IS', 'Gomez-Merino D', 'Geers L', 'Guo C', 'Subhadeep D', 'Muangpaisan W', 'Wagenaar-Tison A', 'Seguin D ...
#
#
# 2023: {'Majdi S', 'Wang LM', 'Razza LB', 'Diddi S', 'Wang Y', 'Bellini MJ', 'Wege TE', 'Cheng KH', 'Nuraydin S', 'Wolf W'}
#
#
# 2021: {'Lejeune JA', 'Brandt AE', 'Pengpid S', 'Yang CH', 'Cui F', 'Markaki I', 'Barbeito P', 'Moura BM', 'Spencer RMC', 'McKay RT', 'Jacobs HIL', 'Brombacher TM', 'Shaaban CE', 'Garrett DD', 'Yang VX', 'Nguyen M', 'Lee JJ', 'Silverman W', 'Sloley SS', 'Islam R', 'Lasarov W', 'Maerlender A', 'Eum S', 'Thulo M', 'Silberstein RB', 'Kapasi A', 'He X', 'Pezzolo E', 'Gomez-Marin A', 'Depoortere RY', 'Chen YC', 'Malpas CB', 'Kronbichler L', 'Bilge S', 'Ruggiero RN', 'Roberts G', 'Ucok A', 'Zang F', 'Muth F', 'Anderson EM', 'Vittersø AD', 'Mahmassani HA', 'Farr E', 'Moniruzzaman M', 'Pohl DJ', 'Tüngler A', 'Chien YL', 'Serrano VB', 'Holewijn RA', 'Gupta R', 'Salavati S', 'Kim UJ', 'Augner C', 'Ruisch BC', 'Beretta S', 'Fortier M', 'Arroyo-Ferrer A', 'Wenger MJ', 'Baez S', 'Kojima H', 'Rafael A', 'Puxeddu MG', 'Cheville AL', 'Stein DH', 'Chou CP', 'Crawford MA', 'Belanger R', 'Neter E', 'Rosebrock LE', 'Baars BJ', 'Turner TH', "O'Keeffe K", 'Puga AM', 'Schaap P', 'Ahmed A', 'Heimler B', 'Repple J', 'Richards KC', 'Linssen B', 'Chuang SP', 'Chen HL', 'List EO', 'Best K', 'Schell M', 'Almasi RC', 'Guan CQ', 'Mackinley M', 'Knollman-Porter K', 'Hunter SK', 'Damiano L', "O'Rear AE", 'Heath DS', 'Anglada-Huguet M', 'Rendón-Torres L', 'Khera T', 'Liljenström H', 'Naik H', 'Kavaliunas A', 'Connor DM', 'Ramotowska S', 'Mikos A', 'Myles H', 'Firmino SG', 'Clemente A', 'Navarro E', 'Fishman KN', 'Nguyen PH', 'Monchanin C', 'Nador JD', 'Finch AP', 'Frost NJ', 'Lechner-Scott J', 'Álvarez-Quintero N', 'Machado R', 'Xia Y', 'Haman M', 'van Helvoort MA', 'Baksi S', 'Serra-Mayoral A', 'Togato G', 'Crocco EA', 'Samad N', 'McElroy E', 'Carrillo JÁ', 'Nixon GM', 'Pérez-Miralles F', 'Nardini M', 'Kodama K', 'Bedrov A', 'Petkus AJ', 'Regolin L', 'Pang BWJ', 'Chen X', 'Ho A', 'Isaksson J', 'Davidson JR', 'Salami M', 'Tso IF', 'Bermudez-Martin P', 'George KM', 'Levine DA', 'Tao Q', 'Tian M', 'Santacà M', 'Horvath G', 'Ahmed RM', 'Quinlan C', 'Özaslan Z', 'Sicard V', 'Hegazy R', 'Salehi Z', 'Pedroso RV', 'Gertje EC', 'Faqih NT', 'Kuhnke P', 'Kotha S', 'Gerstein HC', 'De Giorgi R', 'Lindbergh CA', 'Limone P', 'Tiznado D', 'Liu L', 'Eutrope J', 'Soundararajan K', 'Lindholm B', 'Ashok VR', 'Smith JA', 'Taguchi K', 'Liang CK', 'Flores-Aguilar L', 'GBD 2019 Hearing Loss Collaborators.', 'Daou M', 'Medalia A', 'Dercon Q', 'Vinogradov IM', 'Schmithorst VJ', 'Turo S', 'Temprado JJ', 'Miller LM', 'Caunca MR', 'Lugtmeijer S', 'Stickel AM', 'Ookawara S', 'Antonucci LA', 'Zlibinaite L', 'Matchanova A', 'Larnkjær A', 'Turkmen BA', 'Yadav B', 'Vergoossen LWM', 'Rice LC', 'Koumangoye R', 'Fernández-Felipe J', 'Tubbs AS', 'Sugimoto T', 'Fialho Silva IT', 'Moore TL', 'Pabst A', 'Richerson PJ', 'Bohn M', 'Jen HJ', 'Wan HL', 'Denissen S', 'Dekker TEG', 'Pasco JA', 'Dan X', 'Stadler W', 'Seubert-Ravelo AN', 'Luccarelli J', 'Faulkner KM', 'Oh ES', 'Stavroulaki V', 'Perlman M', 'Britten RA', 'Londzin P', 'Bento AFG', 'Muscat SM', 'Yon D', 'Edwards KM', 'Ochiai H', 'Abanmy N', 'Fisher VJ', 'Bowler S', 'Ferguson L', 'Cárcamo J', 'Vaskinn A', 'Oppegaard K', 'McIntire LK', 'Sheppard E', 'Berg EL', 'Hoyles L', 'Ciria A', 'Bugalho P', 'Ben Ayed I', 'Rowe CJ', 'Razali NAM', 'Kramer HJ', 'Puhlmann LMC', 'Naguy A', 'Völter C', 'Seaman SC', 'Atiya NAA', 'Lyu D', 'Parlar ME', 'Ballweg T', 'Fang M', 'García-Laredo E', 'Hall BA', 'Bailey M', 'Deckers K', 'Foster NN', 'Depping MK', 'Flores DV', 'Withey SL', 'García AM', 'Seitz BM', 'Tecwyn EC', 'Sul S', 'Vreijling SR', 'Wenig K', 'Wakim KM', 'Wallace LMK', 'Huang H', 'de Andrade JE', 'Fahimi A', 'Smith EE', 'Lin L', "D'Arcy RCN", 'Parrino L', 'García-Hermoso A', 'Lea R', 'Lau J', 'Bu J', 'Redlicka J', 'Hakim AM', 'Asher AL', 'Sin E', 'Fogh SE', 'Ma S', 'Bell TR', 'Den Daas C', 'Gupta A', 'Barone R', 'Alexander S', 'Smith R', 'Cooley SA', 'Koohi N', 'Calderón-Garcidueñas L', 'Potvin S', 'Cheong MJ', 'Stanley J', 'James L', 'Danner RM', 'Yuan F', 'Canevelli M', 'Emmert NA', 'Smith T', 'Kumar N', 'Fu P', 'Weiss J', 'Simmons JM', 'Fang F', 'Graves ...
#
#
# 1993: {'Hesse FW', 'Reid WH', 'Cacabelos R', 'Thompson PJ', 'de Jonge MC', 'Baddeley AD', 'Steward MS', 'Corrigan PW', 'Handley SL', 'Stark KD', 'Storey E', 'McPherson L', 'Levine MJ', 'Freeman EW', 'Rosselli M', 'Ardila A', 'Légeron P', 'Meyer JS', 'Barbee JG', 'Ball K', 'Salive ME', 'Kirmayer LJ', 'Miall RC', 'Howe ML', 'Davis WM', 'Mahler EM', 'Kuncheva L', 'Wenestam CG', 'Pisoni DB', 'Perani D', 'Barr RD', 'Karbe H', 'Grünberger J', 'Jonides J', 'Glueck CJ', 'Stiefel F', 'van den Bosch RJ', 'Van Zandt T', 'Tettenborn B', 'Silver JM', 'Clark RD', 'Schneiders J', 'Galski T', 'Aubin-Brunet V', 'Laugel V', 'Nahhas N', 'Konen A', 'Kirkpatrick PJ', 'Dave UP', 'Koss E', 'McClelland JL', 'Lachs MS', 'Lewis MD', 'Cohen LM', 'Bhattacharya SK', 'Glickstein JK', 'Joanette Y', 'de Boer I', 'Koch C', 'Jones BN', 'Tomer R', 'Miklos GL', 'Koponen HJ', 'Bullock TH', 'Plomin R', 'Mercier P', 'Van Hoesen GW', 'Meichenbaum D', 'Botez-Marquard T', 'Shiffrin RM', 'Mauri M', 'Fitzsimmons AS', 'Halford WK', 'Dooling EC', 'Molloy DW', 'Becker J', 'Petrill SA', 'Butler RW', 'Davidoff J', 'Llinás R', 'Devinsky O', 'Caplan R', 'Goetz KL', 'Durwen HF', 'Diesfeldt HF', 'Wilson LD', 'Tecott LH', 'Yayou K', 'Roland PE', 'Ferreira C', 'Soorani-Lunsing RJ', 'Segal HG', 'Fiske ST', 'Leventhal BL', 'Watabe S', 'Sugimori S', 'Suzuki F', 'Manders E', 'Matthews SG', 'Miller IO', 'Lubeck DP', 'Tanaka T', 'Hummer P', 'Chelen W', 'Pollitt E', 'Windsor BL', 'Connolly KJ', 'Knowlton BJ', 'Orsini JJ', 'Vitaliano PP', 'Deutschländer A', 'Plecko B', 'Danion JM', 'Fielder JF', 'Nadler JD', 'Polk M', 'Weisglas-Kuperus N', 'Goldberg TE', 'Tandon OP', 'Salzman C', 'Flint AJ', 'Cohen SA', 'Lee MA', 'Emmorey K', 'Beaudin M', 'Lee LT', 'Mecacci L', 'Lescohier I', 'Cardeña E', 'Meador KJ', 'Saint-Cyr JA', 'Sevush S', 'Ling CX', 'Hecht A', 'Bogdanovic N', 'Meneilly GS', 'Wimo A', 'Karson CN', 'Jenkins IH', 'Aspley S', 'Ogden JA', 'Pinza M', 'Dubrovsky B', 'Hubble JP', 'Pujol J', 'Sazbon L', 'Rappoport L', 'Fisher P', 'Halle MT', 'Raymond GV', 'Patel VL', 'Simons AD', 'Kibel DA', 'Ishiyama FI', 'Kappes B', 'Stoudemire A', 'Murphy ST', 'Thompson EP', 'Mastrangelo M', 'Horikoshi T', 'Růžička E', 'Raj BA', 'Pridham KF', 'Ghitza O', 'Rotter M', 'Segal ME', 'Brooks-Gunn J', 'Karoly P', 'Levine JM', 'Battaglia A', 'Porsolt RD', 'Claypoole KH', 'Morrow JD', 'Gold JM', 'Smith SE', 'Osman A', 'Fischhof PK', 'Bunce DJ', 'Slovenko R', 'Dauphinee WD', 'Rubin EH', 'Kelley TM', 'Benke T', 'Chance B', 'Ashcraft MH', 'Yavich L', 'Levin HS', 'Lucchi L', 'Ordonez J', 'Kuan ML', 'Möller AT', 'Boone KB', 'Launer M', 'Govoni S', 'Biederman J', 'Miller TP', 'Halligan PW', 'Caccia S', 'Gazzaniga MS', 'Nagoshi CT', 'Hollin CR', 'McEntee WJ', 'Block RI', 'Warren M', 'Schlageter K', 'Botez MI', 'de C Williams AC', 'Walter T', 'Thomas JB', 'Werner G', 'Friedrich J', 'Preda L', 'Lasar M', 'Pitsikas N', 'Ghoneim MM', 'Kramer AF', 'Taylor CM', 'Aoki K', 'Feeny D', 'Penner KA', 'Kocsis JH', 'Robertson LC', 'Carter CW Jr', 'Fiedler K', 'Smith AF', 'Ratey JJ', 'Krishnamurthy M', 'Helmstaedter C', 'Howieson DB', 'Convit A', 'Millar MG', 'Rupniak NM', 'Kirk A', 'Algase DL', 'Port R', 'Avants SK', 'Whisman MA', 'Teasdale JD', 'Chiriboga CA', 'Eifert GH', 'Hartman CR', 'McGrath PJ', 'Kalra L', 'Waters MF', 'Ohyama M', 'Rickards AL', 'Weingartner HJ', 'Ohira H', 'Verma NP', 'Andrade C', 'Evans DA', 'Woolf TF', 'McLeod P', "O'Carroll RE", 'Beard JL', 'Nordberg A', 'Dellasega C', 'Costa PT Jr', 'Gerhardt P', 'Pelleymounter MA', 'Wauquier A'}
#
#
# 2019: {'Wilson RS', 'Pengpid S', 'Josefsson A', 'Groeneveld ON', 'Nakajima R', 'Arican C', 'Inglés M', 'Malinowski J', 'Lee JJ', 'Goodman JV', 'Xia H', 'Borghesani V', 'Xu M', 'Hakkers CS', 'Buschert V', 'Kim MS', 'Lammers S', "O' Donovan F", 'Mascialino G', 'Kapasi A', 'Loftis JM', 'Asp EW', 'Kovelman I', 'Chen YC', 'Mayburd AL', 'Brett BE', 'Roberts G', 'Rosenblat JD', 'García-Fernández L', 'Tang F', 'Muth F', 'Chong JSX', 'Ihde D', 'Kroes MCW', 'Povolo CA', 'Diao TX', 'Yue S', 'Navarrete M', 'Sharp JL', 'Becher KF', 'Bove RM', 'Fortier M', 'Arzimanoglou A', 'Wenger MJ', 'Baez S', 'Silva RMFLD', 'Mitchnick KA', 'Jain S', 'Chari S', 'Ohnemus D', 'Ahmed A', 'Richards KC', 'Weakley A', 'Chuang SP', 'Roberts AI', 'Shen J', 'Renczés E', 'Salehi P', 'Kutas M', 'Courtin E', 'Murphy C', 'Blanchard DC', 'Kiebs M', 'Del Olmo N', "O'Rear AE", 'Newey R', 'Lafo J', 'Fiatarone Singh MA', 'Yang SQ', 'Oagaz H', 'Mana J', 'Croijmans I', 'Kim NJ', 'Williams TA', 'Kavaliunas A', 'Malinin LH', 'Djonlagic I', 'Hegberg NJ', 'Yeo TY', 'Labad J', 'Myles H', 'Dewey J', 'Lee JR', 'Wang LS', 'Fishman KN', 'Carlson JM', 'Morimoto K', 'Demsky CA', 'Patniyot NS', 'Airenti G', 'Antico L', 'Chen CLH', 'Povinelli DJ', 'Olagunju AT', 'Cheng XQ', 'Pearce AM', 'Deck BL', 'Wallace SE', 'Knapstad MK', 'de Assis Brasil ES', 'Fiacco S', 'Cramer RJ', 'Romosan AM', 'Zhou XD', 'Ter Mors BJ', 'Fröhlich M', 'Kampling H', 'Chen X', 'Isaksson J', 'Iggena D', 'Bertisch SM', 'Koole SL', 'Khan IS', 'Sun HP', 'Lotze M', 'Cliff JH', 'Stander J', 'Taylor MK', 'Steward A', 'Levine DA', 'Bentvelzen AC', 'Hazama Y', 'Mitter H', 'Antonelli M', 'Ahmed RM', 'Sicard V', 'Mendonça C', 'Bréchemier D', 'Di Daniele N', 'Xiao Y', 'Holmlund TB', 'Liu L', 'Brownlee WJ', 'Lindholm B', 'Younes L', 'Austin CA', 'Howe PRC', 'Hong SJ', 'Munion AK', 'Gilboa Y', 'Medalia A', 'Gjerde PB', 'Wong LC', 'Malek-Ahmadi M', 'Bakoyiannis I', 'Artusi CA', 'Adhikari BM', 'Bernard K', 'Temprado JJ', 'Yeh PY', 'Caunca MR', 'Feczko E', 'Gehrer NA', 'Bennabi D', 'Merli GJ', 'Crum AJ', 'Hongisto MT', 'Sirois K', 'Sofologi M', 'Vitriolo A', 'Was C', 'Schmidt SJ', 'Antoine S', 'Specketer K', 'Denissen S', 'Yokokura M', 'Sargin D', 'Plasmans K', 'Montoya-Murillo G', 'Goldberg SE', 'Young CM', 'Nkyekyer J', 'Oh ES', 'Bangert MK', 'Yon D', 'Aten JD', 'Hendy AM', 'Tanibe T', 'Vaskinn A', 'Lorgen-Ritchie M', 'Chang YJ', 'Bugalho P', 'Thomas M', 'Chi NF', 'Arias M', 'Joseph DJ', 'Villarreal AE', 'Gunderson EA', 'Chernick D', 'Ben-Itzchak E', 'Reichenberger J', 'Blackwood J', 'Rosenberg A', 'Cao B', 'Mostile G', 'Moyano P', 'Deckers K', 'Cao P', 'Lopez Lopez C', 'Qu N', 'García AM', 'Remor AP', 'Moorcroft A', 'Wallace LMK', 'Berg CN', 'Reichelt AC', 'Fuentes-García JP', 'van Rijn S', 'Lin L', 'Castellano CA', 'Papeo L', 'Weightman MJ', 'Sato H', 'Levada OA', 'Leszczynski M', 'Stavrinou LC', 'Hendrix SB', 'Simpson J', 'Gerretsen P', 'Murray DR', 'Norrick NR', 'Jacobs CS', 'Malete L', 'Rosenblatt A', 'Kanie A', 'Gami-Patel P', 'Gupta A', 'Yamada M', 'Goodrich RI', 'Andrade FCD', 'Smith R', 'Ichinose M', 'Lauer JE', 'Oghagbon EK', 'Calderón-Garcidueñas L', 'Ward RT', 'Takeuchi H', 'Silveira C', 'Ocklenburg S', 'Canevelli M', 'Brockmeier J', 'Gao T', 'Alviar C', 'Davies A', 'Ukkola-Vuoti L', 'Post A', 'Thampy H', 'Zhou S', 'Lee KS', 'Labrie N', 'Schneider LS', 'Bradley ER', 'Oh J', 'Monserud MA', 'Bohr AD', 'Engen MJ', 'Demirgan S', 'Lei F', 'Siegel JK', 'Falco F', 'Mavroudis I', 'Martin A', 'Liu Q', 'Tripathi M', 'Golub Y', 'Maki Y', 'Salman T', 'Grinberg Y', 'Reinders Folmer CP', 'Iseli R', 'Fountoulakis KN', 'Weber E', 'Crow AJD', 'Marzoli D', 'Thielke LE', 'Ma J', 'Bates MLS', 'Knoblich U', 'de Macedo Dantas TH', 'Guo C', 'Perone S', 'Harmsen IE', 'Butler PM', 'Sünram-Lea SI', 'Juliano LM', 'Nomi JS', 'AlDakheel A', 'Sun D', 'de Alcântara C', 'Lunardelli ML', 'Talarico G', 'Lee JY', 'Thelengana A', 'Mott SH', 'De Bartolo D', 'Marino RA', 'Nag S', 'Fakhouri Filho SA', 'Wu T', 'Ben-Ari H', 'Komanduri M', 'Ottoy J', 'Formisa ...
#
#
# 2020: {'Jackson JM', 'Pellicano E', 'Andres M', 'Cui F', 'Markaki I', 'Brombacher TM', 'Nakajima R', 'Nisha SN', 'Garrett DD', 'Gómez-Ibáñez A', 'Nguyen M', 'Parola A', 'Bernard F', 'Hornsby AN', 'Hütter M', 'Kawasaki A', 'Sparto PJ', 'Dirupo G', 'Noto S', 'Xu M', 'Hakkers CS', 'Kapasi A', 'Joly-Amado A', 'Meli R', 'Ramirez Ortega D', 'Khine WWT', 'Grattan DR', 'Niu X', 'Duncan PW', 'Natovich R', 'Pennington L', 'Chow FC', 'García-Fernández L', 'Tang F', 'Smichenko J', 'Moniruzzaman M', 'Bohm-Levine N', 'Boudelaa S', 'Janusz J', 'Doering BK', 'Pfeffer S', 'Zhong H', 'Mazur LB', 'Jain S', 'Leyhe T', 'Kleinbub JR', 'Unruh KE', 'Johansson T', 'Mehling WE', 'Carr DB', 'Togay B', 'Shen J', 'Taneja MK', 'de Flores R', 'Luo YL', 'Poncin A', 'Kashihara K', 'Stilling J', 'Koganemaru S', 'Croijmans I', 'Naik H', 'Samara A', 'DiGirolamo AM', 'Petrova T', 'Zhang JW', 'Soerensen M', 'Labad J', 'Biedenweg K', 'Gupta V', 'Roper RJ', 'Holleman GA', 'Kim SK', 'Koizumi A', 'Quevenco FC', 'Viviani R', 'Vlachos II', 'Kawada T', 'Firth NC', 'Bunjo Z', 'Wotherspoon JM', 'Cárdenas-Figueroa A', 'Krawczyk MM', 'Hackney ME', 'Xia Y', 'Lachat Shakeshaft Y', 'Hulme B', 'Cramer RJ', 'Jaworski T', 'Fröhlich M', 'Petkus AJ', 'Kampling H', 'Chen X', 'Rane S', 'Hatukai T', 'Jinpiao Z', 'Leisman G', 'Turana Y', 'Çetin FH', 'Chatterjee S', 'Tso IF', 'Taylor MK', 'Nakai T', 'Levine DA', 'Ling L', 'Lanctôt KL', 'Ciraolo MF', 'Santacà M', 'Antonelli M', 'Konijnenberg E', 'Seo MS', 'Richter N', 'Nieman DH', 'Langdon R', 'Ronold EH', 'Ahmed RM', 'Yeh WH', 'Kuhnke P', 'Puia G', 'Lindbergh CA', 'Liu L', 'Cavalcante BR', 'Smith JA', 'Rodijk LH', 'Rojas-Ferrer I', 'Daou M', 'Rambod M', 'Ceccaldi E', 'van Lier R', 'Maneshi MM', 'Gjerde PB', 'Kano F', 'Malek-Ahmadi M', 'de Almondes KM', 'Ludwig NN', 'Brenowitz WD', 'Caunca MR', 'Maric V', 'Gehrer NA', 'Stickel AM', 'Broersen LHA', 'Antonucci LA', 'Mohsin AKM', 'Tanzer T', 'Rubiño JA', 'Gutman D', 'King DJ', 'Martínez-López I', 'Eckerdal P', 'Ross SR', 'Pabst A', 'Richerson PJ', 'Ferguson AC', 'Montoya-Murillo G', 'Reed SK', 'Luccarelli J', 'Andravizou A', 'Coad BM', 'Hielkema T', 'Oh ES', 'Vaccarino AL', 'Yuan Y', 'Westover KD', 'Sejnoha Minsterova A', 'Muscat SM', 'Ulivi L', 'Ando T', 'Hadidi Zavareh AH', 'Batouli SAH', 'Vaskinn A', 'Broncel A', 'Batzu L', 'Steinman J', 'Heitmann H', 'Velickaite V', 'Naguy A', 'Völter C', 'Disney AA', 'Apaijai N', 'Schubiger MN', 'Lichtenberg PA', 'Rosenberg A', 'Chirico M', 'Rault JL', 'Morales N', 'Fang M', 'Murgia M', 'High RA', 'Korte M', 'Adeel A', 'Huang WY', 'Li YQ', 'Bellens A', 'Simonoff E', 'Valentina IG', 'Zakharova-Luneva E', 'Lee GH', 'Qu N', 'Withey SL', 'Kwon SJ', 'García AM', 'Hochman S', 'Tham DSY', 'Wallace LMK', 'Huang H', 'Verhagen NJE', 'Bland AR', 'Giacomini ACVV', 'van Rijn S', 'Shi YL', 'Lin L', 'Smith EE', 'Fusi G', 'Papeo L', 'García-Hermoso A', 'Hu EA', 'Bermudez CI', 'Pinheiro AP', 'Tatsiy VY', 'Ladegard K', 'Kangaslampi S', 'Inoue DS', 'Buvarp D', 'Guerrera CS', 'Schülke O', 'Deffner D', 'Ma S', 'Cherng YG', 'Anjum MF', 'Kim SH', 'Adebiyi O', 'Gupta A', 'Smith R', 'Reshetnikov VV', 'Calderón-Garcidueñas L', 'Liem NT', 'Gomes ECC', 'Sim JE', 'Canevelli M', 'Lyons R', 'Huynh HP', 'Benavente KSK', 'Milenkovic I', 'Golovina E', 'Josev EK', 'Ghaemi Kerahrodi J', 'Ferreira RC', 'Mella N', 'Lee KS', 'Schneider LS', 'Ottesen NM', 'Oh J', 'Gordon R', 'Domingo D', 'Hardingham GE', 'van Teffelen MW', 'Ardèvol-Abreu A', 'Jantzie LL', 'Martin A', 'Watanabe S', 'Wu ZW', 'Peters N', 'Ryan AT', 'Ng A', 'Vinueza-Veloz MF', 'He D', 'Maki Y', 'Guo DH', 'Mayer JD', 'Mendoza SA', 'Kenworthy L', 'Liu CC', 'Martínez-Díaz IC', 'Narison R', 'Forcano L', 'Vinciguerra F', 'Lengel D', 'Witt JK', 'Kumar D', 'Cremers LGM', 'Maillart E', 'Pérez-Ros P', 'Yeates P', 'Oyedeji CI', 'Meng D', 'Wright A', 'Long F', 'Ma J', 'Hassevoort KM', 'Neikter J', 'Subhadeep D', 'Shiro M', 'van den Berg E', 'Cardin V', 'Crouse JJ', 'Pelcher I', 'Andrew A', 'Schertz HH', 'Ahrenfeldt LJ', 'Paez AG', 'Wettasin ...
#
#
# 2013: {'Shigaeff N', 'White CN', 'Blank T', 'Nagapan G', 'Epperson CN', 'Wilson RS', 'Köhler S', 'Cerami C', 'Delavande A', 'Kim JH', 'Sharip S', 'Clements-Stephens AM', 'Nguyen HT', 'Mueser KT', 'Karakuła H', 'Bertelsen G', 'Lipatova O', 'Peters KR', 'Colom R', 'Keay L', 'Kasckow JW', 'Sperling RA', 'Taillia H', 'Lee JJ', 'Martínez K', 'Cowen P', 'Rahm C', 'Morton FB', 'Rosen GD', 'Babiloni C', 'Casper ML', 'Bloch M', 'Xu M', 'Treasure J', 'Tonoike M', 'Cummins DD', 'Albert D', 'Thompson HE', 'Piccinini G', 'Basatemur E', 'van Almenkerk S', 'Gobbini MI', 'Peleg-Sagy T', 'Janicki SC', 'Ruiz de Azua S', 'Le XT', 'Abu-Akel A', 'Kadohisa M', 'Dzulkifli MA', 'Mihalik JP', 'Vogt T', 'Pine KJ', 'Sosnoff JJ', 'Francis H', 'Irish M', 'Rapisarda A', 'Harciarek M', 'Mortamais M', 'Gitter SA', 'Arauz A', 'Buddingh S', 'Ronan JL', 'Festman Y', 'Hogan CL', 'Mitra S', 'Devore EE', 'Bauernfeind AL', 'Fan X', 'Gur RC', 'Herd SA', 'Hertrich I', 'Nieto A', 'Fox MC', 'Gygi B', 'Bedrosian TA', 'Siniatchkin M', 'Morris GP', 'Metzger CD', 'Dastjerdi M', 'Panos SE', 'Beck C', 'Spikman JM', 'Peng Y', 'Rizzi TS', 'Prehn K', 'Duron E', 'Bender AC', 'Murphy GM Jr', 'Fisch GS', 'Zaiken K', 'Tapajóz Pereira de Sampaio F', 'Baez S', 'Egyed K', 'Haazebroek P', 'Paton B', 'Mitchell MB', 'Hensley K', 'Nandhra HS', 'Hill TW', 'Yang X', 'Zaidel DW', 'Mennenga SE', 'Matoso JM', 'Dunn W', 'von Vogelsang AC', 'Kucian K', 'Baines T', 'Rochat MJ', 'Eckert MJ', 'Pettersson-Yeo W', 'Koelsch S', 'Chalermpalanupap T', 'Henningsen K', 'Michael RB', 'Turner TH', 'Sacher J', 'Pexman PM', 'Easton A', 'Sharma R', 'Mier D', 'Perkins KA', 'Clarke R', 'Kroll JF', 'Musilli M', 'Harré M', 'Agis-Balboa RC', 'McClung JS', 'May M', 'Cady R', 'Chilcot J', 'Joosten-Weyn Banningh LW', 'Lucas N', 'Zuelsdorff ML', 'Milhau A', 'Shen J', 'Aalbers T', 'Stange I', 'Franco-Martín M', 'Matsukawa N', 'Mutschler I', 'Fini C', 'Eack SM', 'Hariprasad VR', 'Rennie SM', 'Muhlert N', 'van Zwieten A', 'Mittal VA', 'Zajenkowski M', 'Ho SS', 'Clouston SA', 'Lyseng-Williamson KA', 'Yu A', 'Kraft R', 'Kubit B', 'Blumberg FC', 'Lasikiewicz N', 'Octave JN', 'Mueller SC', 'Olivera La Rosa A', 'Eisen A', 'Voelcker-Rehage C', 'Lipina S', 'Johnson EJ', 'Geliebter A', 'Bak TH', 'Hall L', 'Aruru MV', 'Sellaro R', 'Jansen CE', 'Mimura K', 'Vytal KE', 'Kundu B', 'Liu HY', 'Schaefer RS', 'Akawi NA', 'Sumien N', 'Wharton W', 'Schilbach L', 'Kim YH', 'Montebelli A', 'Lach G', 'Mathews M', 'Gentner D', 'Fonseca MI', 'van der Vlies AE', 'Jarome TJ', 'Finke K', 'Moser CM', 'van den Brink D', 'Prayson BE', 'Chau KH', 'Boyce CA', 'Halvorson KM', 'Lord LD', 'Kooistra M', 'Zell E', 'Shaw DJ', 'Mender D', 'Chapman HA', 'Michel NM', 'Minagar A', 'Herrmann PA', 'Guzman VA', 'Jacobs DW', 'Thaler NS', 'Vuoksimaa E', 'Bistricky SL', 'Jhaveri DJ', 'Hogervorst E', 'Dean PM', 'Verhaaren BF', 'Barbato M', 'Knops A', 'Törnqvist H', 'van Esch TE', 'Shulman MB', 'Elison JT', 'Mano QR', 'Lucassen PJ', 'Zorzi M', 'Gunn HJ', 'Megreya AM', 'Strassnig M', 'Ward J', 'Liu HC', 'Park D', 'Pakyurek M', 'Melloni M', 'Williams AC', 'Amato MP', 'Zhu XY', 'Quattlebaum JL', 'Patron E', 'Vengoechea J', 'Proal E', 'Ortigo KM', 'Kosnes L', 'Takahashi Y', 'Suvada J', 'Lo Baido R', 'Sherman BL', 'Simons CJ', 'Sozio P', 'Markou A', 'Yuan L', 'Henderson VW', 'de Groot MW', 'Svenningsson A', 'Magal A', 'Leisman G', 'Mapelli D', 'Al Aïn S', 'Bassani S', 'Boksem MA', 'Praetorius M', 'Levine B', 'Holloway T', 'Krainik A', 'Li C', 'Fehr T', 'Dadalto L', 'van der Kooi AW', 'van Ruitenbeek P', 'Sandjaja', 'Kerr CW', 'Yang SH', 'Handattu SP', 'Torniainen M', 'Strand TA', 'Levine DA', 'Tonning Olsson I', 'Blackburn D', 'Tell V', 'Beauchet O', 'Voss P', 'Ferro MA', 'Kapusta A', 'Gharaeipour M', 'Mingrone C', 'Perry MS', 'Ahmed RM', 'Govaerts MJ', 'Curlik DM 2nd', 'Chi H', 'Fulton ML', 'Pedersen KF', 'Holding JC', 'Lench HC', 'Wirth M', 'Hornslien AG', 'Liu T', 'Crichton GE', 'Stacey WC', 'Juan E', 'Gregoire SM', 'Tost H', 'Tarapore PE', 'Kenna H', 'Chopra A', 'Cranmer ...
#
#
# 2018: {'Abreu W', 'Quera-Salva MA', 'Jacobs HIL', 'Brombacher TM', 'Fisk AS', 'Nakajima R', 'Canhada S', 'Inglés M', 'Avrunin GS', 'Patel A', 'Bernard F', 'Yerlikaya D', 'Honn KA', 'Giardino V', 'Gavriloff D', 'Thompson HE', 'Kapasi A', 'Kanayet FJ', "O'Donoghue MC", 'López-Hurtado A', 'González-Forero M', 'Ng TP', 'Korol DL', 'Chen YC', 'Natovich R', 'Schlicht T', 'Koncz R', 'Tang F', 'Anderson EM', 'Pot-Kolder RMCA', 'Rogers-Soeder TS', 'Donix M', 'Laurent R', 'Wade J', 'Borg E', 'Grabyan JM', 'González-Garrido AA', 'Zagorska A', 'Noone C', 'Pfeffer A', 'Fatfouta R', 'Yuhi T', 'Baez S', 'Zhong H', 'Antonsen KK', 'Lotan A', 'Searles S', 'Kucian K', 'Blanchet S', 'Augoustinos M', 'Jacobson SW', 'Fedra E', 'Richard AD', 'Thompson GA', 'Bo Q', 'Machado A', 'Shen J', 'Sabeti S', 'Wyman-Chick KA', 'Trojano L', 'Best K', 'Lundwall RA', 'Vinberg M', 'Frumer Y', 'Hübner D', 'Murphy C', 'Qiu WY', 'Desmarais P', 'Vasylenko O', 'Stubbs B', 'Ranlund S', 'Harvey J', 'Sarubbo F', 'Fishman KN', 'Nguyen PH', 'Soyata AZ', 'Iigaya K', 'Żuromski D', 'Viviani R', 'Antico L', 'Clayton MS', 'Lind RR', 'Olagunju AT', 'Bates V', 'Hui CW', 'Wissman KT', 'Samad N', 'Bertini E', 'Matheson SM', 'Chen X', 'Crockford CJ', 'Isaksson J', 'Russo R', 'Abawi M', 'Caruana F', 'Feinkohl I', 'Yang SH', 'Tso IF', 'Liew SL', 'Taylor MK', 'Levine DA', 'Tan PZ', 'Bugos J', 'Ahmed RM', 'Lee KM', 'Sicard V', 'Pedroso RV', 'Ellingsen DM', 'Janke K', 'Müller S', 'Lindbergh CA', 'Bucci P', 'Green SA', 'Sinkeviciute I', 'Meles SK', 'Bolden LB', 'Cavalcante BR', 'Whittington MA', 'de Boer A', 'Howe PRC', 'Hong SJ', 'Roy MA', 'Ballard ED', 'Tucker D', 'Zhou A', 'McQuillan MA', 'Kano F', 'Fernandez-Gonzalo S', 'Kusch M', 'Malek-Ahmadi M', 'Apple AC', 'Petrakova A', 'Kim HH', 'Al-Ayadhi L', 'Bennabi D', 'Paine AL', 'Crum AJ', 'Negida A', 'Hilari K', 'Cardilini APA', 'Yabut OR', 'Da Rold F', 'Bohn M', 'Rebholz H', 'Spano G', 'Bailey KA', 'Gingins S', 'Nkyekyer J', 'Passerieux C', 'Gkika S', 'Ohmuro N', 'Woo DH', 'Colvin LE', 'Yon D', 'Vaskinn A', 'Yerys BE', 'Devenney E', 'Roger E', 'Brinkley TE', 'Cavazza M', 'Mestre TA', 'Völter C', 'Tan E', 'Rosenberg A', 'Vakilinezhad MA', 'Cao B', 'Lichtenberg PA', 'De Meijer L', 'Olusanya AW', 'Hanken K', 'Díez-Cirarda M', 'Radd-Vagenas S', 'Pringe H', 'Rosa LA', 'Lopez C', 'Keenan EG', 'Chowthi-Williams A', 'Cao P', 'Gossink F', 'Boyd B', 'García AM', 'Dunne AL', 'Saad MA', 'Huang H', 'Pantzar A', 'Reichelt AC', 'Hughes JEA', 'van Rijn S', 'Newman TP', 'Bae GY', 'Daher I', 'Gladding JM', 'Conejero I', 'Drayson Z', 'Kim SH', 'Pettijohn KA', 'Barnes-Holmes Y', 'Gupta A', 'Barone R', 'Momtaz YA', 'Fechner HB', 'Güçlütürk Y', 'Karawani H', 'Potvin S', 'Cheong MJ', 'Takeuchi H', 'Daniels AK', 'Kim GW', 'Tolin DF', 'Scherer RW', 'O’Rourke DP', 'Balci B', 'Dou H', 'M Elicer I', 'Muhammad S', 'Spivey MJ', 'MAL-ED Network Investigators .', 'Aresi G', 'Zhou S', 'McNamara RA', 'Eisenberg ML', 'Oh J', 'Freedman DJ', 'Jantzie LL', 'Marchand NE', 'Martin A', 'Horat SK', 'Lurie DI', 'Elharram M', 'Kepecs DM', 'Lozupone M', 'Leshner G', 'Cruz-Sanabria F', 'Juretić J', 'Weatherhead D', 'Nunn CL', 'Huber CM', 'Hughes ML', 'Comrie AE', 'Setti A', 'Witteman J', 'Smesny S', 'Fujishiro H', 'Sevel LS', 'Phillips NJ', 'Gehring WJ', 'Marzoli D', 'Dempsey AG', 'Meng D', 'Antonini A', 'Ma J', 'Hayes HA', 'Guastella AJ', 'Chang JK', 'Perone S', 'Verma A', 'Lock AM', 'Menning S', 'van Ede F', 'Whitelock V', 'van den Berg E', 'Foley DL', 'Barnes-Holmes D', 'Chae JJK', 'Huang JY', 'Crouse JJ', 'Andrew A', 'Fredman Stein K', 'Ashton BJ', 'Gulmez Karaca K', 'Spruijt AM', 'Wattjes A', 'Alexander BH', 'Hong WJ', 'Koga S', 'Chang H', 'Yu S', 'Sánchez-Gutiérrez T', 'Houvenaghel JF', 'Lanser I', 'Hajjar I', 'Dawson A', 'Treichler EBH', 'Melnik A', 'Wingenbach TSH', 'Groen Y', 'Terry DP', 'Hullick C', 'Taylor ME', 'Lorenz R', 'Yaple Z', 'Huang CC', 'La Gattuta E', 'Intzandt B', 'Morgan KN', 'Fernandes RM', 'Hochberger WC', 'Mistry S', 'Payton NM', 'Martinez G', 'Avram M', 'Be ...
#
#
# 2017: {'Blank T', 'Wilson RS', 'Marino L', 'Cui F', 'Brombacher TM', 'Nakajima R', 'Arowoiya AI', 'Reike D', 'Lou W', 'Martínez K', 'Skidmore ER', 'Yao S', 'Arshad Q', 'Wohlwend M', 'Huded CP', 'Dzogang F', 'Einarsson A', 'Eum S', 'LeDoux JE', 'Morozov YM', 'González-Forero M', 'Chen YC', 'Kronbichler L', 'Hadders-Algra M', 'Roberts G', 'Ai J', 'Rosenblat JD', 'Sors A', 'Cappelli C', 'Kroes MCW', 'McDonnell A', 'Naughton P', 'Navarrete JA', 'Turner AD', 'Kozlovsky DY', 'Hinson VK', 'Wenger MJ', 'Baez S', 'Bécamel C', 'Ouellette DR', 'Kojima H', 'Zuo L', 'Dewenter J', 'DeDominicis KE', 'Suo C', 'Turner TH', 'Reingold EM', "O'Leary K", 'Leinenger M', 'Spira AP', 'de Jong IEM', 'Heimler B', 'Bo Q', 'Yap KH', 'Trojano L', 'Kikuchi M', 'Vinberg M', 'Oleson S', 'Clouston SA', 'Murphy C', 'Cowden Hindash AH', 'Darwish H', 'Reuber M', 'Mader S', 'Rich JV', 'Grober E', 'Burgess PW', 'Stubbs B', 'Applebaum EV', 'Ferguson MA', 'Canfield CF', 'Nguyen PH', 'Kim SK', 'Heaney M', 'Stronen AV', 'Casey DA', 'Viviani R', 'Finch AP', 'Kawada T', 'Moody CJ', 'Bell SP', 'van Buren B', 'Frankenhuis WE', 'Stessman J', 'Hancock L', 'Deck BL', 'Wallace SE', 'Alba AC', 'Colman W', 'Chen X', 'Meyer A', 'Iggena D', 'Freeman S', 'Caruana F', 'Gunier RB', 'Seyed Majidi N', 'Tso IF', 'Warren AEL', 'Horvath G', 'Pienaar IS', 'Langdon R', 'Pedersen KF', 'Robinson RA', 'Laws SM', 'Müller S', 'Train the Brain Consortium.', 'Lindbergh CA', 'Nowparast Rostami H', 'Fields JA', 'Keller HH', 'Young KS', 'Salmazo-Silva H', 'Liu L', 'Çakcı A', 'Bolden LB', 'Huang SF', 'Jamison R', 'Liang CK', 'Vassilopoulos SP', "O'Shea H", 'Medalia A', 'Hernandorena I', 'Macpherson F', 'Elenbaas L', 'Kano F', 'Malek-Ahmadi M', 'Liu ZM', 'Watt MJ', 'de Almondes KM', 'Isenberg-Grzeda E', 'Apple AC', 'Johnson SA', 'Nielsen HM', 'Wolf C', 'Mamelak M', 'Lacey L', 'Masana MF', 'Colmenares F', 'Civile C', 'Axelrod V', 'Kang EC', 'Makale MT', 'Heitz C', 'Moore TL', 'Koski SE', 'An JY', 'Jaswal S', 'Schneider CB', 'Henry MS', 'Yeh CW', 'Garcia-Chimeno Y', 'Oh ES', 'Ekerstad N', 'Yon D', 'Ku PW', 'Carter FA', 'Vaskinn A', 'Toots A', 'Yerys BE', 'Lugert S', 'Campos CH', 'Monteiro-Junior RS', 'Völter C', 'MacDonald SW', 'Blackwood J', 'Bernhardt BC', 'Brier S', 'Mao CV', 'Landen JW', 'Blain-Moraes S', 'Swaddle JP', 'Ekroll V', 'Aghaei I', 'Deckers K', 'Lordo DN', 'Zai G', 'Takemoto-Kimura S', 'Tecwyn EC', 'Naicker SN', 'Huang H', 'Payne HL', 'Waljee JF', 'Reichelt AC', 'Pantzar A', 'Smit DJA', 'de Carvalho LM', 'Blume J', 'Gur TL', 'Castellano CA', 'García-Hermoso A', 'Daher I', 'Hammami-Abrand Abadi A', 'Zhang HQ', 'Gerretsen P', 'Niwald M', 'Hauser SL', 'Ma S', 'Alexandrou AM', 'Owen L', 'Kim SH', 'Parrott AC', 'Gupta A', 'Smith R', 'Moisan F', 'Allum JHJ', 'Calderón-Garcidueñas L', 'Potvin S', 'Takeuchi H', 'Torika N', 'Sayapina NV', 'Athanasiu L', 'Bradley ER', 'Mollaei N', 'Wright RS', 'Pagan F', 'Liu Q', 'Horat SK', 'Martín Contero MC', 'Ayán C', 'Goossens T', 'Sinke C', 'Verguts T', 'Gardner MR', 'Boiteau TW', 'Witt JK', "O'Hare C", 'Visser TAW', 'Gong WY', 'Thielke LE', 'Seymour K', 'Meng D', 'Watts AL', 'Antonini A', 'Ma J', 'Oakes MA', 'Lowthian JA', 'Perone S', 'Boot N', 'Sünram-Lea SI', 'van Ede F', 'Petit G', 'Seguin D', 'de Hevia MD', 'Kornblith S', 'Nomi JS', 'Sun D', 'Karthikeyan S', 'Agnew-Blais J', 'Delbroek T', 'Sankar A', 'Niedeggen M', 'Weimer AA', 'Chang H', 'Samamé C', 'Nag S', 'Trujillo SP', 'Ajami M', 'Hajjar I', 'Melnik A', 'Chen W', 'Thubert T', 'Taylor ME', 'Silverberg ND', 'Itzhaki RF', 'Darrell-Berry H', 'Schindler SE', 'Barwick F', 'Bridges K', 'Martinez G', 'Pinto LF', 'Silberschmidt S', 'Cantillon M', 'Wang GY', 'Mathys J', 'Noël X', 'Joubert L', 'Moore MR', 'Frederikse P', 'Pratama M', 'Schaich Borg J', 'Locci A', 'Hess NC', 'Deckert J', 'Homenko JG', 'Nerhus M', 'Myers PS', 'Gronau QF', 'Schroeder PA', 'Callisaya ML', 'Scheltens NME', 'Medaglia JD', 'Cao A', 'Ma X', 'Chung MC', 'Dayon L', 'Shalash AS', 'Mahoney JJ', 'Hasegawa Y', 'Campbell SA', 'Stepanichev M', ...
#
#
# 2015: {'Fonollosa J', 'Wilson RS', 'Andres M', 'Crawford TJ', 'Paruthi S', 'Sinkus ML', 'Braga-Neto P', 'Bhattacharya TK', 'Finn M', 'Kauffman SA', 'Lee JJ', 'Martínez K', 'Skidmore ER', 'Patel A', 'Sheridan MB', 'Nongonierma AB', 'Sutliff S', 'Jorgensen LE', 'Ng TP', 'Korol DL', 'Chen YC', 'Malpas CB', 'Wu YS', 'Krabbe S', 'Rosenblat JD', 'Kunkel A', 'Nevalainen N', 'Lehne M', 'Smith MJ', 'Inoue A', 'Moniruzzaman M', 'Morland C', 'Chien YL', 'Turner AD', 'Hipkiss AR', 'Noone C', 'Fish JE', 'Ponto LL', 'Snyder KP', 'Corbetta M', 'Bumoko GM', 'Baez S', 'Mennenga SE', 'Ireland JL', 'Armstrong JJ', 'Remberk B', 'Roberts AI', 'Wyman-Chick KA', 'Shen J', 'Patzke N', 'Silveira S', 'Clouston SA', 'Dudev T', 'Vredeveldt A', 'Ley T', 'Pantelis PC', 'Magistrale G', 'Smith AP', 'Malinin LH', 'Murthy VS', 'Gladilin E', 'Iqbal N', 'Berger LM', 'Sarubbo F', 'Nitkowska M', 'Kim SK', 'Montuschi A', 'van der Velde F', 'Hackney ME', 'Rahe J', 'Maillard AM', 'Colman W', 'Chen X', 'Diakidoy IA', 'Chatterjee S', 'Tso IF', 'Meinow B', 'Levine DA', 'Ward DD', 'Zanghi BM', 'Salvato G', 'Bhattacharjee A', 'Hurley RS', 'Lodeiro-Fernández L', 'Jagust WJ', 'Lindholm B', 'Keutmann MK', 'Meles SK', 'Peláez VC', 'Oldfield RG', 'Fernandez-Gonzalo S', 'Kano F', 'Malek-Ahmadi M', 'Brenowitz WD', 'Al-Sukhni M', 'Lacey L', 'Notwell JH', 'Corrigall KA', 'Julian GS', 'Ries JD', 'Heitz C', 'Remmelink E', 'Ahn YH', 'Colón K', 'Murman DL', 'Alfimova MV', 'Brodbeck MI', 'Yeh CW', 'Ohmuro N', 'Aslan AK', 'Yuan Y', 'Hoehne A', 'Jabaris SS', 'Fredrick MM', 'Lynch ME', 'Volf NV', 'Vaskinn A', 'Verweij M', 'Holmes GL', 'Conti S', 'Devenney E', 'Deardorff WJ', 'Afghan Z', 'Jedrychowski MP', 'Edwards S', 'Cao B', 'Schofield CA', 'Bock J', 'Brier S', 'Hunter DS', 'Dere E', 'Scheinert RB', 'Berrut G', 'Cruickshank TM', 'Pantzar A', 'Mitchell AW', 'Klein N', 'van Rijn S', 'Castellano CA', 'Lin L', 'Smith EE', 'Papeo L', 'Ko KI', 'Malhotra R', 'Kountouras J', 'Fabre D', 'El Batsh MM', 'Gerretsen P', 'Ma S', 'Uhlhaas PJ', 'Archer SJ', 'Yamada M', 'Cacciari C', 'Borst JP', 'Smith R', 'Calderón-Garcidueñas L', 'Potvin S', 'Takeuchi H', 'Doherty BM', 'Yannakoulia M', 'Canevelli M', 'Osso LA', 'Stine-Morrow EA', "O'Connell K", 'Hunt KL', 'Musso M', 'Sperry SH', 'Bockaert J', 'Bartels DM', 'Shapouri S', 'Soska KC', 'Ocampo B', 'Ng A', 'He D', 'Seliger SL', 'van Rijsbergen GD', 'Stephens RG', 'Mak E', 'Cheraghi F', 'Sinke C', 'Ince RA', 'Setti A', 'Fujishiro H', 'Lehtonen A', 'Gobin CM', 'Yeates P', 'Havekes R', 'Marchi F', 'Ma J', 'Buchtel EE', 'Wood PL', 'Lang K', 'Vendetti MS', 'Thorsteinsdóttir SA', 'Guastella AJ', 'Menning S', 'van Ede F', 'Tieges Z', 'Stringer TP', 'Nomi JS', 'Biggs AT', 'Androsova G', 'Sun D', 'Anders S', 'Koh DH', 'Fields LM', 'Lee JY', 'Mohn TC', 'Samamé C', 'Guerino MR', 'Strejilevich SA', 'Hajjar I', 'Galanopoulou AS', 'Bagney A', 'Carson DS', 'Spruijt S', 'Mewborn C', 'Zahara AR', 'Risoli A', 'Weiss MW', 'Nickels L', 'Redcay E', 'Wubs AG', 'Caller TA', 'Jongbloed W', 'Johnson ED', 'Soler ZM', 'Vohs JL', 'Zordan MA', 'Gabrielian S', 'Shen X', 'Wang GY', 'Avraamides MN', 'Duclot F', 'Lecci F', 'Antonucci N', 'Lv MH', 'Hochgräfe K', 'Andrade C', 'Lee KB', 'Carta MG', 'Redfern C', 'Schroeder PA', 'Callisaya ML', 'Medaglia JD', 'Sink KM', 'Apter JT', 'Mönninghoff C', 'Plewnia C', 'Pellecchia MT', 'Alquezar C', 'Costa V', 'Park JL', 'Newton DF', 'Yıldız Mİ', 'Braverman ER', 'Leppänen JM', 'Daugherty AM', 'Piccoli T', 'Steuwe C', 'Mercedes Perez-Rodriguez M', 'Harrison DM', 'Kojima S', 'Horr T', 'Pies R', 'Sigurdsson T', 'Beckes L', 'Shah AK', 'Bayat M', 'Jabaris SG', 'Dinkelbach L', 'Iuliano E', 'Riva S', 'Peres MA', 'Gavilán JM', 'Chen H', 'Mendella PD', 'Villalba K', 'Tate MC', 'Leidy HJ', 'de Macedo LD', 'Mellendijk L', 'Lin Y', 'Dachtler J', 'Olivier B', 'Chu CH', 'Butler LP', 'Wallin KG', 'Gascon M', 'Fett AK', 'Michalski B', 'Xiao L', 'Hinkelmann K', 'Atkinson J', 'Aarts S', 'Le Guen O', 'Cohen-Manheim I', 'Lee SA', 'Rao SK', 'Malabade R', 'Feltmann K', 'Ng ...
#
#
# 2012: {'Sadato N', 'Waters KA', 'Nahm M', 'Miletto Petrazzini ME', 'Wilson RS', 'Biddie SC', 'Epperson CN', 'Poehlmann J', 'Meijer J', 'Moritz-Gasser S', 'Nebieridze N', 'Ubeda N', 'Kim JH', 'Sepulcre J', 'Nguyen HT', 'Aggarwal NT', 'Favaro A', 'Brinda EM', 'Liu YW', 'Berg JE', 'Sheehan B', 'Deroo M', 'Perea M', 'Schober ME', 'Hodge AB', 'Bennett JS', 'Cohen AD', 'Babiloni C', 'Braunewell KH', 'Hanney M', 'Treasure J', 'Kunos CA', 'de la Sayette V', 'Reginold W', 'Blümel JE', 'McConnell MM', 'Rönnemaa E', 'Eckstein MP', 'Seo SW', 'Burke KE', 'Slagter HA', 'Uitti RJ', 'Köhler M', 'Ayotte BJ', 'Aiken-Morgan AT', 'Hayman LA', 'Ng TP', 'Wagenmakers EJ', 'Kroupi E', 'dos Santos IB', 'Chen YC', 'Kaleem MA', 'Wilkinson D', 'Religa D', 'Szűcs V', 'Meijer JH', 'Haberman RP', 'Rose SA', 'Peters SU', 'Marosi K', 'Gildengers AG', 'Smith MJ', 'Derinoz O', 'Pernigo S', 'Devore EE', 'Herbert BM', 'Gur RC', 'Poda R', 'Chamberlain SE', 'Nieto A', 'Ohadi M', 'Popovics P', 'Hung LW', 'Fleisher L', 'Fogelman D', 'Seegmüller C', 'Luck SJ', 'Gupta R', 'Jacquin A', 'Spikman JM', 'Sridharan A', 'Cox CL', 'Nathan PJ', 'Bruce J', 'Young J', 'Soh SE', 'Duron E', 'Katona C', 'Szelag E', 'Lee GJ', 'Han SD', 'Thorvaldsson V', 'Wacker DW', 'Baez S', 'Luppa M', 'Semenova S', 'Grundey J', 'Knapp C', 'Healy SD', 'Mitchell MB', 'Ries ML', 'Johansson MM', 'Levinson SC', 'Cassidy SM', 'Babaei R', 'Teixeira-Leite H', 'Brandon M', 'de Manzano Ö', 'Jain S', 'Watson MR', 'Fu M', 'Legare CH', 'Martins E', 'Ireland JL', 'Armstrong JJ', 'Baars BJ', 'Thomas LA', 'Petrou M', 'Schmalenberger S', 'Peña J', 'Spira AP', 'Cohen CI', 'Kimiskidis VK', 'Remberk B', 'Custer JW', 'Kralik JD', 'Veldhuijzen DS', 'Eack SM', 'Peer E', 'Huang YJ', 'Ho SS', 'Peterson A', 'Clouston SA', 'Nagashima T', 'Roser P', 'Hung WW', 'Johnson EJ', 'Masciopinto F', 'Puschmann A', 'Cheng MJ', 'Bak TH', 'Schiöth HB', 'Klencklen G', "Vasil'eva EV", 'Strutt AM', 'Xiang B', 'Halder S', 'Graham R', 'Wharton W', 'Silva JLD', 'Schilbach L', 'Harris SE', 'Okamura A', 'Vesterager L', 'Higuera-Matas A', 'Landers MS', 'González-Burgos I', 'Bargh JA', 'Eren MI', 'Vreugdenhil A', 'Meffre J', 'Wirz-Justice A', 'Palaci F', 'Shaw DJ', 'Okonkwo OC', 'Ward RD', 'Stein J', 'Rooney B', 'Hattori K', 'Harvey J', 'Bohl V', 'Dash SR', 'Bosch B', 'Terry CP', 'Preiss M', 'Hogervorst E', 'Koutsouleris N', 'Carter SF', 'Wikgren M', 'Spocter MA', 'Lucassen PJ', 'Vos E', 'Yoshida K', 'Tsai KT', 'Ross PD', 'Murray LL', 'Maglio SJ', 'Shimazaki H', 'OʼHara R', 'Park D', 'Osório J', 'Lan Z', 'Dong ZY', 'Brodsky MB', 'Amanullah S', 'Pelov I', 'Puranik CS', 'Cruz-Martín A', 'Fedorenko E', 'Weiss S', 'Thornton A', 'Briscoe J', 'Kelley AM', 'Reini SA', 'Terry AV Jr', 'Chen X', 'Manly T', 'Jaques JA', 'Srivastava S', 'Sforza E', 'Xu JM', 'Willi R', 'Lukazewski A', 'Henderson VW', 'Lee SW', 'Fietta P', 'Cagliani R', 'Lai JS', 'Tamura M', 'Tamayev R', 'Stoodley CJ', 'Feinkohl I', 'Robson H', 'Li C', 'Post JB', 'Purtzer MA', 'Spires-Jones T', 'Sui L', 'Tso IF', 'Roberts DL', 'Snyder JS', 'Zorumski CF', 'Monsell SE', 'Ybarra O', 'Johansson EM', 'Lévesque M', 'Xu Z', 'Liu T', 'Horan WP', 'Chantiluke K', 'Ralevski E', 'Mansur RB', 'Brown EC', 'Abner EL', 'Merritt PS', 'Byrne MD', 'Watson GE', 'Crichton GE', 'Corey-Bloom J', 'Eaton JM', 'Heo JH', 'Dodd MD', 'Dickinson A', 'Callaghan CK', 'Tone EB', 'Gilad R', 'Ashrafi F', 'Cioffi J', 'den Ouden HE', 'Sunil HV', 'Soto ME', 'Silverstein SM', 'Richardson DC', 'Lu AS', 'Xue S', 'Shah RC', 'Shanahan M', 'Burbank KS', 'Tastet H', 'Raftery G', 'Javitt DC', 'Lee RS', 'Marsman JB', 'Kervern M', 'Barbosa RR', 'Medalia A', 'Metzler-Baddeley C', 'Dos SF', 'Crasto CL', 'Olai L', 'Steenweg ME', 'Malek-Ahmadi M', 'Penner IK', 'Medow JE', 'Glanzman DL', 'Everson R', 'Pluncevic J', 'Millan MJ', 'Elkins DN', 'Martin-Khan M', 'Arkin RC', 'Hannan AJ', 'Hoeft B', 'Hong SL', 'Genizi J', 'Vlak T', 'Shearer J', 'Awad AG', 'Zisapel N', 'Roca-Stappung M', 'Fryer SL', 'Halliday KE', 'Onore C', 'Oh H', 'Di Biasio F', 'Pinha ...
#
#
# 2016: {'Wilson RS', 'Van Bruggen S', 'Spencer RMC', 'Groeneveld ON', 'Lamb R', 'Huo S', 'Lee JJ', 'Fling BW', 'Arshad Q', 'Kim MS', 'Chubala CM', 'Thompson HE', 'Gomez-Marin A', 'Natovich R', 'Kessler RM', 'Szűcs V', 'Madureira S', 'Nuijten M', 'Gildengers AG', 'Fatima M', 'Graziane JA', 'Drgonova J', 'Wokke ME', 'Gulec Suyen G', 'Dawson GR', 'Noone C', 'Fabbri E', 'Bove RM', 'Baez S', 'Alkadri J', 'Muir-Hunter SW', 'Tamber-Rosenau BJ', 'Johansson MM', 'Mitchell MB', 'Brier MR', 'Clark-Wilson J', 'Ireland JL', 'Suo C', 'Armstrong JJ', 'Carr DB', 'Shen J', 'Wyman-Chick KA', 'Lo SB', 'Vinberg M', 'Sahu G', 'Pool LR', 'Vredeveldt A', 'Yang SQ', 'González-Pinto A', 'Wen K', 'López-Gil JM', 'Schilbach L', 'Hoang P', 'Kline AE', 'Smith AP', 'Van Hecke A', 'Bergareche A', 'Stubbs B', 'Labad J', 'Hasan SM', 'Canfield CF', 'Orff HJ', 'Zarrabipoor H', 'Cole WR', 'Staff RT', 'Kawada T', 'Schwartz AC', 'Bell SP', 'Maglio SJ', 'Halonen J', 'Cramer RJ', 'Chen X', 'Ampatzis K', 'Karpouzian TM', 'Paulo T RS', 'Del Brutto OH', 'Freeman S', 'Vishwanathan R', 'Dwyer GM', 'Uemura K', 'Dor-Ziderman Y', 'Kotilainen T', 'Jiwani S', 'Sui G', 'Ahmed RM', 'Zanghi BM', 'Gallant H', 'Salvato G', 'Brown EC', 'Xiao Y', 'Juan E', 'DuPre E', 'Li YW', 'Puente AE', 'Al-Bayati AR', 'Hirshfield S', 'Norenzayan A', 'Stauffer CS', 'Gray SA', 'Diaz-Siso JR', 'Vanhaute H', 'Elenbaas L', 'Siemers ER', 'Malek-Ahmadi M', 'Prinka', 'Beattie JF', 'Rentzsch J', 'A Sanchez C', 'Meyer HC', 'Madre M', 'Axelrod V', 'Mata IF', 'Torrence ND', 'Sugimoto T', 'Conty L', 'Kusec A', 'Remmelink E', 'Jaswal S', 'Bohn M', 'Salehi R', 'Holden MP', 'Zhu F', 'Skillings EA', 'Alfimova MV', 'Peitsch L', 'Davis S', 'Simons DJ', 'Ohmuro N', 'Keane KM', 'Vaccarino AL', 'Gregg JA', 'Rudra A', 'Sokhadze EM', 'Wetherill RR', 'Blackmer AB', 'McCarthy JM', 'Liouta E', 'Volz KG', 'Holmes GL', 'Crocker E', 'Devenney E', 'Li PC', 'Taylor EM', 'Bugalho P', 'Zussy C', 'von Gunten A', 'McLennan SN', 'Caulfield F', 'Heitmann H', 'Villarreal AE', 'Monteiro-Junior RS', 'Rucklidge JJ', 'Deardorff WJ', 'Kierkegaard M', 'Graveson J', 'Blackwood J', 'Lopez C', 'Ekroll V', 'Hunter DS', 'Sörensen BM', 'Bernheim A', 'Dean AM', 'Brubaker L', 'Qu N', 'García AM', 'Berlyand Y', 'Burley CV', 'Havelka D', 'Huang H', 'Bland AR', 'Josef N', 'Reichelt AC', 'Kerster BE', 'Hwang TY', 'Butler AA', 'Deschamps L', 'Hardy CJ', 'Tornick JK', 'Udriştoiu I', 'Althaus N', 'Yehuda S', 'Hajari N', 'Bernstein MH', 'Horchak OV', 'Gualtieri F', 'Kim SH', 'Pettijohn KA', 'Pru JK', 'Gupta A', 'Yamada M', 'McGrath LM', 'Larsen IU', 'Smith R', 'Lauer JE', 'Calderón-Garcidueñas L', 'Potvin S', 'Castelhano MS', 'Takeuchi H', 'Jamrozik A', 'Cibelli E', 'Ocklenburg S', 'Canevelli M', 'Griñan-Ferré C', 'Kumar N', 'Reichenberg A', 'Mormino EC', 'Schipper S', 'Janson CH', 'Valdes EG', 'Ribarič S', 'Oh J', 'Robson SJ', 'Eisenberg ML', 'Berry TR', 'Hardingham GE', 'Martin A', 'Liu Q', 'Hattori M', 'Lackner N', 'Wickens CD', 'Jorgensen DR', 'Hsieh CS', 'Goossens T', 'Weatherhead D', 'Moghadasi AN', 'Suárez-Pellicioni M', 'Steffener J', 'Romano-López A', 'Szűcs D', 'Wong RHX', 'Sreekrishnan A', 'Anelli F', 'Seymour K', 'Bae JS', 'Brønnick K', 'Lang K', 'Deeley Q', 'Correa Á', 'Guo C', 'Wilber ST', 'Marzagalli R', 'Rodríguez-Míguez E', 'Dunbar RI', 'Wasserman RM', 'Schroeder EL', 'Nomi JS', 'di Porzio U', 'Sun D', 'Geiszler PC', 'Brucki SM', 'Martínez G', 'Ahrenfeldt LJ', 'Choy KH', 'Fischi-Gomez E', 'Lee JY', 'de Neve-Enthoven NG', 'Oosterman JM', 'Taschereau-Dumouchel V', 'Houvenaghel JF', 'Hajjar I', 'Don HJ', 'Lockwood Estrin G', 'Chen W', 'Yeung MK', 'McDermott EE', 'Silverberg ND', 'Tandon PS', 'Meyer BM', 'Caller TA', 'Fluegge K', 'Pisani SL', 'Hochberger WC', 'Vohs JL', 'Kliper E', 'Mehling W', 'Särkämö T', 'Forsman L', 'Cacchione T', 'Allan C', 'Ko C', 'Veena SR', 'Lawrence Z', 'Lauenroth A', 'Resnick B', 'Coffman BA', 'Andrade C', 'Higueras-Fresnillo S', 'Kharabian Masouleh S', 'Kalbe E', 'Schroeder PA', 'Callisaya ML', 'Grasset L', 'Ma X', ' ...
#
#
# 2014: {'García-Montes JM', 'Sedda A', 'Lipatova O', 'Finn M', 'Soysal AS', 'Dale E', 'Xu M', 'Cummins DD', 'Sigaudo M', 'Kanayet FJ', 'Hall CC', 'Childs E', 'Ng TP', 'Kovelman I', 'Mai F', 'Roesch S', 'Palm R', 'Anderson A', 'Sadler BM', 'Callenmark B', 'Simmonds DJ', 'Marosi K', 'Smith MJ', 'Greenlee MW', 'Livingston G', 'Vella K', 'Gargiulo PÁ', 'Lees R', 'Chinta S', 'Baez S', 'Bumoko GM', 'Perrels AJ', 'Muir-Hunter SW', 'Thompson JR', 'Pipingas A', 'Clark-Wilson J', 'Mennenga SE', 'Leyhe T', 'Sankar T', 'Spira AP', 'Goodman R', 'Keer M', 'Shen J', 'Schultze-Lutter F', 'Preskorn SH', 'Méndez JC', 'Kaerst L', 'Schneider EH', 'Pantelis PC', 'Ursino M', 'Schilbach L', 'Marijnissen RM', 'Schott GD', 'Djonlagic I', 'Samara A', 'Stubbs B', 'Ferguson MA', 'Fitzgibbon L', 'Carlson JM', 'Bøen E', 'Saldert C', 'Viviani R', 'Prigatano GP', 'Rutter AR', 'Liu ME', 'Zimmermann R', 'Lucassen PJ', 'Stessman J', 'Gökçen E', 'Yates BJ', 'Chen X', 'Leisman G', 'Buchanan A', 'Christofoletti G', 'Turana Y', 'Caruana F', 'Vishwanathan R', 'Lee TT', 'Tso IF', 'Wheeler L', 'Drugowitsch J', 'Levine DA', 'Lanctôt KL', 'Bencherif M', 'Ahmed RM', 'Ward DD', 'Langdon R', 'Evans AH', 'Salvato G', 'Brown EC', 'Lindbergh CA', 'Sideli L', 'Paban V', 'Fields RD', 'Sass LA', 'Heusch A', 'Liang CK', 'Willmott C', 'Medalia A', 'Sezgin Z', 'Ninomiya Y', 'Thirsk LM', 'Smithies V', 'Burdick DJ', 'Anderson JW', 'Laksov KB', 'Ingelman-Sundberg M', 'Bokor G', 'Wilms IL', 'Holshausen K', 'Stupple EJ', 'Eriksson K', 'Vaskinn A', 'Holmes GL', 'McIntire LK', 'Gentile DA', 'Bernhardt BC', 'Graf CE', 'Wiemers M', 'Lopez C', 'Aghaei I', 'Lim HK', 'Yamamoto J', 'García AM', 'Tecwyn EC', 'Popova P', 'Broadbent H', 'Mitchell AW', 'Pulopulos MM', 'van Rijn S', 'Waddell B', 'Weightman MJ', 'Sato H', 'Gill MJ', 'Odlaug BL', 'Mulugeta E', 'Kanie A', 'Parrott AC', 'Rao JA', 'Ostergard T', 'Park G', 'Staniloiu A', 'Victorson D', 'Calderón-Garcidueñas L', 'Potvin S', 'Takeuchi H', 'Downer EJ', 'Martin MG', 'Subhedar NK', 'Reichenberg A', 'Mormino EC', 'Reisi P', 'Lambon Ralph MA', 'Mortensen HS', 'Lin FH', 'Martin A', 'Watanabe S', 'Dao AT', 'Reilly JB', 'Mak E', 'Liu CC', 'Trivedi MH', 'Cusick A', 'Steffener J', 'Kim BK', 'McCoy SK', 'Valmas MM', 'Yu SH', 'Anelli F', 'Ma J', 'Vendetti MS', 'Perone S', 'Tristan I', 'Tachibana R', 'de Hevia MD', 'Sun D', 'Cogsdill EJ', "D'Hondt F", 'Tops M', 'Tsarenko SV', 'Yegla B', 'Lee JY', 'Nielsen AB', 'Guare R', 'Yu S', 'Galland L', 'Picking R', 'Hoepner R', 'Kroken RA', 'Phu AL', 'Aas M', 'Grèzes J', 'Masip D', 'Chen W', 'Factor SA', 'Huang CC', 'Scheerer N', 'Ochola S', 'McKinnon A', 'Saito A', 'Avram M', 'Cheuvront SN', 'Vohs JL', 'Farnam A', 'Lindman BR', 'Iidaka T', 'Särkämö T', 'Shimojo S', 'Astrand E', 'Hamilton HK', 'Lafortune M', 'Coffman BA', 'Palmer SM', 'Callisaya ML', 'Barnea-Goraly N', 'Sink KM', 'Young AH', 'Hoeft F', 'Ebner NC', 'de Oliveira MO', 'Mok LW', 'Shiraishi N', 'Proietti R', 'Bensch M', 'Stouten LH', 'Braverman ER', 'Stephens R', 'Keogh E', 'Haslam C', 'Steuwe C', 'Wolff JG', 'Cooper JC', 'Li X', 'Lauretani F', 'Peters ME', 'Lidzba K', 'Fornells-Ambrojo M', 'Chase HW', 'Zwaan RA', 'Akshoomoff N', 'Pulman J', 'Fischer BL', 'Lin Y', 'Brandt T', 'Zilinski J', 'Brown JW', 'Butler LP', 'Schmidt SL', 'Stiller JW', 'Fett AK', 'Xiao L', 'Lim S', 'Choi SM', 'Frederick DE', 'Putcha D', 'Balzan RP', 'Chakravarty S', 'Passmore P', 'Marghetis T', 'Deliens G', 'Daly S', 'Vannorsdall TD', 'Klein E', 'Wobber V', 'Cooter R', 'Eitam B', 'Xiong K', 'Qian X', 'Reiter J', 'Füllgrabe C', 'Hoche F', 'Powell ES', 'Rosas A', 'Lee CI', 'Draganich C', 'Crystal JD', 'Rabiei Z', 'Brei TJ', 'Bernini M', 'Hamilton JL', 'Razlighi QR', 'Ludwig D', 'Gelman SA', 'McDonough IM', 'Jincai W', 'Poeppl TB', 'Khosravizade Tabasi H', 'Bosia M', 'Neuman MD', 'Schnell K', 'Filmer HL', 'Werner P', 'Kimani S', 'Karatsoreos IN', 'Rozenman M', 'Hamilton JM', 'McLaren IP', 'Alexander SK', 'Dauvermann MR', 'Brodaty H', 'Reilly JL', 'Kim KU', 'Greggor AL', 'Veijola J',  ...
#
#
# ...
#
#
# 1989: {'Seshadri S', 'Zimmermann M', 'Hertzig ME', 'Hodges JR', 'Rousey CL', 'Farre Albaladejo M', 'LaFarge L', 'Wesnes KA', 'Gallistel CR', 'Coles MG', 'Merlini L', 'Clarkson-Smith L', 'Seki N', 'Katayama M', 'Kroonenberg PM', 'Reber AS', 'Sherman SJ', 'Prather E', 'Meyer JS', 'Athlin E', 'Kavanagh DJ', 'Pearson JL', 'Kuisk LA', 'Friedman PJ', 'Spohn HE', 'Donovan DM', 'McCormick DA', 'Young B', 'Rüther E', 'Eimas PD', 'Shucard DW', 'Berger HJ', 'Arima Y', 'Greenwald BS', 'Jackson RD', 'Palermo DS', "O'Mahony JF", 'Done DJ', 'Saugstad LF', 'Wenk GL', 'Komaroff AL', 'Piattelli-Palmarini M', 'Rogers RL', 'Parks RW', 'Bellinger D', 'Chichinadze NK', 'Gitlin MJ', 'Németh G', 'Vogt H', 'Christensen KJ', 'David AS', 'Easterling DV', 'Derouesné C', 'Kakigi R', 'Harris BH', 'Liben LS', 'Hynd GW', 'Azmitia M', 'Brunstein JC', 'Mongrain S', 'Schlegel S', 'Myslobodsky MS', 'Cummings JL', 'Shuttleworth EC', 'Trbović M', 'Brady JV', 'Thal D', 'Peralta Martín V', 'Loeb C', 'Renvall MJ', 'Costall B', 'Tang XF', 'Mohr E', 'Rogers SJ', 'Barry P', 'Robbins M', 'Newhouse PA', 'Koponen H', 'Swartz KP', 'Lazarova-Bakarova MB', 'Hecht A', 'Varela FJ', 'Todd JT', 'Loewenstein DA', 'Ueno M', 'Gurevitch D', 'Etou H', 'Goldberg EH', 'Whitehouse PJ', 'Wrona-Polańska H', 'Weisz JR', 'Telander RL', 'Huber SJ', 'Schindler U', 'Kriel RL', 'Wettstein A', 'Jackson LA', 'Teri L', 'Norris-Baker C', 'Pliszka SR', 'White KG', 'Spaulding W', 'Kaiho S', 'Fröstl W', 'Myhrer T', 'Pape HC', 'Pepeu G', 'Gelenberg AJ', 'Spaulding SJ', 'Oyu J', 'Gauthier S', 'Brown RH', 'Amado-Boccara I', 'Rohrer JE', 'Crawley JN', 'Kuprianov SIu', 'Whitaker JJ', 'Martin I', 'Thal LJ', 'Lasser NL', 'Braham J', 'Gottesman RL', 'Johanson A', 'Leconte P', 'Sakamoto A', 'Berger RS', 'Schaffler K', 'Mysiw WJ', 'Dohr KB', 'Daston L', 'Sebban C', 'Richardson JT', 'Breckler SJ', 'Schwartz R', 'Beahrs JO', 'Fundudis T', 'Mayes LC', 'Vida S', 'Naugle RI', 'Ashikaga M', 'Rock I', 'Jennekens-Schinkel A', 'Fabrega H Jr', 'Petkov VD', 'Pack DR', 'Rupniak NM', 'Changeux JP', 'Hunter R', 'Posener JA', 'Torún B', 'Kelly CA', 'Fior R', 'Reuter BM', 'Newman S', 'Caramazza A', 'Lewicki P', 'Furedy JJ', 'Smith BD', 'Clark DA', 'Robins CJ', 'Foster NL', 'Hashimoto S', 'Foreman MD', 'Iwasaki Y', 'Goldstein RL', 'Kassirer JP', 'Mintun MA', 'Karli P', 'Mamelak AN'}
#
#
# 1988: {'Wilson RS', 'Callahan CW Jr', 'Malatesta CZ', 'Säveland H', 'Sunderland T', 'Waldrop MM', 'Fennell RS 3rd', 'Meyer JS', "O'Keeffe B", 'Parkins EJ', 'Reed BD', 'Peters CA', 'Abbeduto L', 'Hoff AL', 'Chiarello C', 'Komaroff AL', 'Church KL', 'Mayer JD', 'Corrigan JD', 'Price RW', 'Kawamura M', 'Harter S', 'Olton DS', 'Singer L', 'Lowenstein DH', 'Berman KF', 'Deaconson TF', 'Furukawa M', 'Schab FR', 'Armstrong-James M', 'Shipley-Brown F', 'Tariot PN', 'Kyle NL', 'Preston GC', 'Joffe RT', 'Walker LC', 'Hamann KF', 'Löwy I', 'Fox R', 'Forgas JP', 'Genkova MG', 'Christal RE', 'Hecht A', 'Liang RA', 'Kaiho S', 'Beresin EV', 'Vormbrock JK', 'Hammen C', 'Cermak LS', 'Visser AP', 'Rovner BW', 'Bains GK', 'Keenan MA', 'Ingram RE', 'Bierman CW', 'Berndt RS', 'Syrigou-Papavasiliou A', 'Hodges SA', 'Bassant MH', 'Demitrack MA', 'Weinberger DR', 'Kuhn FJ', 'Verloes R', 'Grady CL', 'Farmer JE', 'Meyer DE', 'Ehrlichman H', 'Aharon-Peretz J', 'Mayer MA', 'Altomare C', 'Salthouse TA', 'Goldman-Rakic PS', 'Trautner RJ', 'Barsky AJ', 'Voorhies TM', 'Amit DJ', 'De Gennaro L', 'Bradley VA', 'Wade DT', 'Davis AR', 'Tanaka JS', 'Connor DJ', 'Umino M', 'Dent J', 'Moos WH', 'Kaszniak AW', 'Meerwaldt JD', 'Petiet CA', 'Parker G', 'Ferris SH', 'Schmitt FA', 'Kurlan R', 'Mohide EA', 'Stern DN', 'Newberger CM', 'Lee M', 'Reischies FM', 'Dantzer R', 'Jordan C', 'Harvey NS', 'Pshennikova MG', 'Camp CJ', "O'Boyle MW", 'Kurth E', 'Bogen JE', 'Pittenger JB', 'Lewis RS'}
#
#
# 1987: {'Witelson SF', 'Carraccio CL', 'Ragin AB', 'Randall CL', 'Kiernan RJ', 'Sunderland T', 'MacLeod C', 'Estrin WJ', 'Spignoli G', 'DeNoble VJ', 'Hamagishi T', 'Pohl MI', 'Koukkou M', 'Albert M', 'Brunko E', 'De Kloet ER', 'Roth FP', 'de Kloet ER', 'Blackburn IM', 'Carroll WR', 'Higgins ET', 'Campbell M', 'Rakel RE', 'Ivnik RJ', 'Cervén E', 'Werry JS', 'Sweetland J', 'Greenswag LR', 'Wagner DA', 'Bridge TP', 'Chavoix C', 'Gur RC', 'Johnston FE', 'Onofrj M', 'Davidson PM', 'Tariot PN', 'Barry PP', 'Brown WT', 'Mechanick JI', 'Hänninen H', 'Beal MF', 'Holyoak KJ', 'Ramachandran VS', 'Corcoran MA', 'Tomm K', 'Forgas JP', 'Hecht A', 'Dodd M', 'Roy-Byrne PP', 'Oscar-Berman M', 'Ohbuchi K', 'Huber SJ', 'Shimizu Y', 'Fuchigami K', 'Hoffman RE', 'Dawson G', 'Ivanov NR', 'Baba M', 'Jones RV', 'Wise TN', 'Testa MA', 'Berent S', 'Axsom D', 'Swann WB Jr', 'Meyer FP', 'Vining EP', 'Levine JM', 'Porsolt RD', 'Ingram RE', 'Maturana HR', 'Smith SE', 'Batson CD', 'Kopp CB', 'Pellegrini DS', 'Levin HS', 'Lam DH', 'Van Dyke C', 'Ananth J', 'Binnie CD', 'Phillips AG', 'Shrager J', 'Nagoshi CT', 'Luxenberg JS', 'Hagberg B', 'Goldman-Rakic PS', 'Foy MR', 'Johnson-Laird PN', 'Lee C', 'Lister RG', 'McCartney CF', 'Shinomoto S', 'Abreu BC', 'Rabins PV', 'Sonesson B', 'Gerner RH', 'Boltenkov EM', 'Price DL', 'Himuro T', 'Sudilovsky A', 'El-Mangoury NH', 'Smith BD', 'Hobson JA', 'Silfverskiöld P', 'Rutter M', 'Hyer L', 'Davis KL', 'Dixit V', 'Kassirer JP', 'Irle E', 'Osberg TM'}
#
#
# 1986: {'Peters HA', 'Zapotoczky HG', 'Meyer JS', 'Zern DS', 'Dix T', 'Growdon JH', 'DeNoble VJ', 'McCloskey M', 'Nicolaides ED', 'McMahon RC', 'Berrios GE', 'Siebens H', 'Grafman J', 'Levine SC', 'de Kloet ER', 'Cheney D', 'Mayor GH', 'Henderson AS', 'Kondo F', 'Turk DC', 'Bolig R', 'Kasai T', "Pal'tsev MA", 'Hay DF', 'Erkinjuntti T', 'Cash TF', 'Dobson KS', 'Landis T', 'Shimooka S', 'Sutherland S', 'Farrell K', 'Bompani R', 'Block J', 'Cynx J', 'Martindale C', 'Jaeger J', 'Cowan N', 'Hatsukami DK', 'Baugh BT', 'Cummings JL', 'Spaulding WD', 'Barnes DM', 'Bird JM', "O'Connor MJ", 'Masten AS', 'Hecht A', 'Kydd RR', 'Schwartz S', 'Torgesen JK', 'Hellige JB', 'Wyer RS Jr', 'Maurer FA', 'Leichner R', 'Short RJ', 'Pepeu G', 'Loosen PT', 'Rush AJ', 'Kay SR', 'Vögele C', 'Levy J', 'Purcell S', 'Capute AJ', 'Tait PE', 'Liberson WT', 'Ayres TJ', 'Cohen RD', 'Eckardt MJ', 'Nagoshi CT', 'Luxenberg JS', 'Schwab EK', 'Javier RA', 'Ghoneim MM', 'Stock WA', 'Jennekens-Schinkel A', 'Ulatowska HK', 'Rosen AM', 'Boss BJ', 'Moskowitz H', 'Brown JM', 'Salazar AM', 'Himuro T', 'Mewaldt SP', 'Spudis EV', 'Bagby RM', 'Hauert CA', 'Gloor P', 'Ottaviano S', 'Hömberg V', 'Bornstein MH', 'Rasbury WC', 'Burns M', 'Wilson GF', 'Steele C'}
#
#
# 1985: {'Mohs RC', 'Eagle RS', 'Hannon R', 'Zapotoczky HG', 'Thorp NL', 'Ingvar DH', 'Sherman M', 'Chang T', 'Ishikawa A', 'Berrios GE', 'Sharpe SL', 'Eslinger PJ', 'Morgan WP', 'Goto Y', 'Rao SM', 'Iwaya K', 'Masendorf F', 'Radilová J', 'Strupp BJ', 'Bergsma J', 'Bates D', 'Grumet GW', 'Siegel GM', 'Hunt HT', 'Iwai E', 'Bennett B', 'Kendall PC', 'Kochergin VN', 'Poschel BP', 'Mattle H', 'Davies P', 'Anderson JR', 'Freeman RL', 'Pinkstaff E', 'Solan HA', 'Epstein R', 'Hajek VE', 'Tucker DM', 'Centa DM', 'London ED', 'Whitehouse PJ', 'Prohaska TR', 'Rutter DR', 'Kai M', 'Wyer RS Jr', 'Sakamoto N', 'Rosenthal MJ', 'Dworkin RH', 'Levine HG', 'George L', 'Garcia J', 'Baker EL Jr', 'Capute AJ', 'Thomae H', 'Ishizaki T', 'Meltzoff AN', 'Orbach I', 'Pellegrini DS', 'Young RC', 'Lahuerta-Palacios JJ', 'Smith PJ', 'Lugovskoĭ EV', 'Buchsbaum MS', 'Valliant PM', 'Organ DW', 'Henck JW', 'Kurita H', 'Shih YH', 'Ghoneim MM', 'Andorfer JC', 'Newman J', 'Naugle RI', 'Gelety TJ', 'Branconnier RJ', 'Chen FP', 'Wulff SB', 'Hommer DW', 'Barden RC', 'Wanner E', 'Folstein SE', 'Lidsky TI', 'Berg CE', 'Velinsky SJ', 'Delmar-McClure N', 'Rutter M', 'Siegal T', 'Arrindell WA', 'Duryea EJ', 'Stern JM'}
#
#
# 1984: {'Davidson G', 'Cook ND', 'Hoffman C', 'Olson RK', 'Colombo A', 'Gunderson JG', 'Rafal RD', 'Maljojoki P', 'Platt JE', 'Breckler SJ', 'López Alonso AO', 'Ghoneim MM', 'Ferguson HB', 'Simons AD', 'Bavosi R', 'Teichmann G', 'Evans GW', 'Newman RP', 'Schneider-Rosen K', 'Martin DJ', 'Kidman A', 'Mislej M', 'Harré R', 'Jones EE', 'Chertok L', 'Numann PJ', 'Levin S', 'Ross RJ', 'Fiedler H', 'Metter EJ', 'Friebe D', 'Frodi A', 'Moskowitz H', 'Lehmann D', 'Ritter W', 'Cummings JL', 'Alias AG', 'Greenfield PM', 'Eiben CF', 'Latimer PR', 'Galey D', 'Glass A', 'Marcoux B', 'McGeer PL', 'Calfee R', 'Hay DA', 'Sowa CJ', 'Parker ES', 'Marsden CD', 'Pinker S', 'Merluzzi TV', 'Beck AT', 'Knippa J', 'Okabayashi H', 'Cacioppo JT', 'Ellison JM', 'Shimp CP', 'Geschwind N', 'Peyser JM', 'McGuigan FJ', 'Besson JA', 'Wells N', 'Port RL', 'Donchin E', 'Meck WH', 'Hughes JR', 'Virgile RS', 'Gazzaniga MS', 'Trudel L', 'Abbott MW', 'Schuckit MA'}
#
#
# 1983: {'Rice ML', 'Holle G', 'Meltzer ML', 'Revers WJ', 'Roemer RA', 'Youngner SJ', 'Strupp BJ', 'Ristau CA', 'Portin R', 'Kühne W', 'Hellige JB', 'Holcomb WR', 'Ingvar DH', 'Hurtig AL', 'Swenson RA', 'Cornell EH', 'Lamiell JT', 'Johnson RC', 'Jack R', 'Hains AA', 'Rothenberg A', 'Otomo E', 'Massey EW', 'Sloate PL', 'Bloom AS', 'Lauth G', 'Chapey R', 'Silberman EK', 'Branconnier RJ', 'Battegay R', 'Grossberg S', 'Roszkowski MJ', 'Youdim MB', 'Strupp B', 'Avorn J', 'Lester EP', 'Folstein SE', 'Teasdale JD', 'Maturana HR', 'Kemler DG', 'Herman JF', 'Levy J', 'Kusché CA', 'Hunt E', 'Gambill JD', 'Arffa S', 'Kenrick DT', 'Greenwald BS', 'Schor DP', 'Lipowski ZJ', 'Thomas PD', 'Mercer L', 'Hay DA', 'Blackburn IM', 'Hopkins B', 'Scuvee-Moreau J', 'Obata T', 'Coyne JC', 'Magaro PA', 'Saito S', 'Mann RE', 'Bernstein RM', 'Holyoak K', 'Davidson AR', 'Silberfarb PM', 'Goodin DS', 'Wright JH', 'Rose SA', 'Rinehart MA', 'Bluestone CD'}
#
#
# 1982: {'Eidelson RJ', 'Mohs RC', 'Wolf TM', 'Wetherby AM', 'Hansch EC', 'DeFries JC', 'Yaroush RA', 'Blacher J', 'Siegrist J', 'Granacher RP Jr', 'Bristow J', 'Sanders B', 'Feighner JP', 'Dolen LS', 'Pollitt E', 'Wood JL', 'Omoto Y', 'Yogman MW', 'Nasrallah HA', 'Johnston JR', 'Kitawaga Y', 'Wisniewski HM', 'Kimball CP', 'Halgren E', 'Tweedy JR', 'Fletcher BA', 'Ruddy MG', 'Kino S', 'Dee A', 'Reisberg B', 'Levin HS', 'Lawton MP', 'Whitton JL', 'Pecyna M', 'Bergman A', 'Cohen RM', 'Wais M', 'Wasserman EA', 'Majovski LV', 'Coles GS', 'Kivenko NV', 'Weingartner H'}
#
#
# 1981: {'Feier CD', 'Jurko MF', 'Neufeld RW', 'Hauser MJ', 'Butler DE', 'Platt JE', 'Müller-Westing H', 'Johnson-Laird PN', 'Trenn TJ', 'Finkler K', 'Gevins AS', 'Turvey MT', 'Mitsuyama Y', 'Basch MF', 'Thompson P', 'Carp FM', 'Rothenberg A', 'Sackeim HA', 'Bierman KL', 'Curtiss S', 'Staddon JE', 'Posner MI', 'Strauss E', 'Mayeux R', 'Minami T', 'Lobato D', 'Oatley K', 'Jenning EA', 'Swinney D', 'Wolpe J', 'Broga MI', 'Cunningham WR', "Shul'ga AI", 'Andrew JM', 'Pollitt E', 'Golden M', 'Lidsky TI', 'Christomanou H', 'Plumb M', 'Hatano K', 'Morton J', 'Thal LJ', 'Hill PM', 'Kessen W', 'Smith B', 'Paris J', 'Yolton JW', 'Beran RG', 'Hochberg J', 'Wilson EO', 'Hibler N', 'Oades RD', 'Vogt W', 'Demuth W', 'Loftus EF', 'Schaeffer J', 'Bluestone CD', 'Browning GB'}
#
#
# 1980: {'Ferraro DP', 'Forer SK', 'Miller JF', 'Takahashi T', 'Ashton GC', 'Gevins AS', 'Ron S', 'Shraberg D', 'Santostefano S', 'Rothenberg A', 'Dabbs JM Jr', 'Dodge KA', 'Ando E', 'Kelly MP', 'Berenbaum SA', 'Philpott WH', 'Risch SC', 'Okawaga F', 'DePaulo JR', 'Ulvund SE', 'Allen JG', 'Horowitz FD', 'Christomanou H', 'Kukla F', 'Hilgard ER', 'Nagler SH', 'Cameron R', 'Farley FH', 'Jacoby LL', 'Sadalla EK', 'Potvin AR', 'Yesavage JA', 'Powell PM', 'Hixson PK', 'Sato T', 'Rubins JL', 'Dieckhöfer K', 'Chui HC', 'Grand S', 'Corley RP', 'Petrovici JN', 'Arieti S', 'Ishiguro T', 'Morehead DM', 'Sappington JT'}
#
#
# 1979: {'Judd LL', 'Johnstone J', 'Taneda M', 'Mitsuyama Y', 'Ploog D', 'Bartus RT', 'Barnett J', 'Rothenberg A', 'Sackeim HA', 'Plum F', 'Cohen LB', 'Lefebvre RC', 'Matsumura Y', 'Peeke SC', 'Malerstein AJ', 'Kohen-Raz R', 'Teschan PE', 'Kaszniak AW', 'Holland VM', 'Caruso IA', 'Gubanov NI', 'Simon HA', 'Murray ME', 'Chess S', 'Gold PW', 'Kiczak J', 'Kashihara E', 'Bukharin OV', 'Smith CM', 'Okaichi H', 'Tower RB', 'Vandenberg SG', 'Chapman LJ', 'Rapin I', 'Kotzan JA', 'Shlechter TM', 'Sachse R', 'Levin HS', 'Rutter M', 'Lubinski R', 'Caplan J', 'Simoneau K', 'Adams MS', 'Dockens WS 3rd', 'Cvetkovic R', 'Fox MJ', 'Lincourt JM', 'Ruble DN', 'Bundy RS'}
#
#
# 1978: {'Nakagawa Y', 'Anderson CO', 'Cohen DB', 'DeFries JC', 'Neisser U', 'Kawada T', 'Sarlin MB', 'Sexton RO', 'Maxwell C', 'Jacques S', 'Frumkin LR', 'Favazza AR', 'Aiba M', 'John ER', 'Wolpe J', 'Isaacsen-Bright M', 'Bunno K', 'Kotzan JA', 'Burwitz L', 'Holroyd KA', 'Birnbaum MH', 'Kihlstrom JF', 'Carey RG', 'Alford B', 'Tsaregorodtsev GI', 'Gloor P', 'Strauss ME', 'Yarnell P', 'Okaichi H', 'Shaw JC', 'Tubert Oklander J'}
#
#
# 1977: {'Bell R', 'Modestin J', 'Beresford HR', 'Schmid P', 'Wolff S', 'Chebysheva LN', 'Brooks PH', 'Harris ME', 'Merikangas JR', 'Wainer H', 'Sokhin AA', 'Buck LA', 'Lindahl MB', 'Freeman HE', 'Zweymüller K', 'Popler K', 'Poulsen H', 'Harness BZ', 'Nevins DB', 'Yi S', 'Chapman LJ', 'Ledoux JE', 'Hamsher KS', 'Johnson JH', 'Haslett NR', 'Kruger P', 'Coursey RD', 'Reed GF', 'Milgram RM', 'Lepper MR', 'Selman RL', 'Lempers JD', 'Noppe LD', 'McGuigan FJ', 'McCall RB', 'Pálvölgyi R', 'Lederman SJ'}
#
#
# 1976: {'Weisz JR', 'Bruce DL', 'Finkelstein FO', 'Schover LR', 'McGoodwin JR', 'Letzel H', 'Cranton PA', 'Gribbin K', 'Ferris S', 'Witelson DF', 'Petlenko VP', 'Platt JJ', 'Parton DA', 'Riklan M', 'Andreasen NC', 'Harness BZ', 'Chandler MJ', 'Bosse K', 'Orlofsky JL', 'Singer RN', 'Granick S', 'Ivanovová L', 'Windmiller M', 'Matheny AP Jr', 'Farley FH', 'Robertson-Tchabo E', 'Holroyd KA', 'Fischer R', 'Kumar S', 'Dieckhöfer K', 'Pauker SG', 'Sillman LR', 'Davis KL', 'Waber DP', 'Werry JS', 'Haynes CD'}
#
#
# 1975: {'Kapusz N', 'Kawasaki S', 'Crapanzano V', 'Enomoto K', 'Mizuno M', 'Yamaguchi T', 'Snezhnevskiĭ AV', 'Weinreb N', 'Kahana B', 'Hoffer MM', 'Lindauer MS', 'Vandenbussche F', 'Clayton V', 'White KS', 'Singh MM', 'Nagai I', 'Okayama M', 'Chiba Y', 'Shiraishi T', 'Kay SR', 'Muhlenkamp A', 'Sheldon EB', 'Yamanaka C', 'Tsutsumi J', 'Affleck GG', 'Potvin AR', 'Taniguchi N', 'Karniol IG', 'Sullivan JA', 'Cole JO', 'Kuroda Y', 'Gakuta T', 'Kitamura Y', 'Shapiro AP', 'Villablanca JR', 'Hargis CH', 'Hibbard TR', 'Murakami C', 'Campbell M', 'Kamiya K', 'Meadow A', 'Paivio A', 'Schwartz GE', 'Kameyama M', 'Atkin S', 'Hand I', 'Marion-Mignon A', 'Ginn HE', 'Donnelly EF'}
#
#
# 1974: {'Morikawa S', 'de Saussure J', 'Weintraub M', 'Rafferty FT', 'Spitz RA', 'Geertsma RH', 'Atkin S', 'Bear G', 'Okayama M', 'Brown JW'}
#
#
# 1973: {'Matsumoto E', 'Muromoto H', 'Kline CL', 'Swets JA', 'Sakamoto K', 'Walberg HJ', 'Benedetti P', 'Riegel KF', 'Chan H', 'Zhdanov VM', 'Puzyński S'}
#
#
# 1972: {'Galin D', 'Houpt JL', 'Hamilton V', 'Klein RE', 'Goldstein D', 'Kubo S', 'Geertsma RH', 'Hatano K', 'Almgren PE', 'Mendelsohn GA', 'Aderman M'}
#
#
# 1971: {'Beck AT', 'Singhal SK', 'Jacobs EA', 'Samotokin BA', 'Bauer ER', 'Adams AE', 'Guignard F', 'Milgram NA', 'Schmidt HD', 'Asaga H', 'Webb RC', 'Fowler W', 'Yabuki S'}

# %% [markdown]
# ### Task 2
#
# Based on the dictionary `first_authors_at_year` from exercise 1 above, create a plot for the years from 1970 until now that shows how many authors published at least one paper as first author in the given particular year.

# %%
years = [year for year,vals in first_authors_at_year.items() if year >=1970]
counts = [len(first_authors_at_year[year]) for year in years]

plt.bar(years, counts)
plt.title('First Authors Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Unique First Authors')
plt.xlim(1970, 2023);
plt.show()

# %% [markdown]
# ### Task 3
#
# Print out the top 10 most often occurring words in the papers' titles together with their frequency, in descending order with respect to the frequency. Filter out words that are only one or two characters long, like `a` or `of`, to only show words that have three or more characters. Use the data structures created above (in the sections before the tasks).

# %%
# filter to only get words longer than two characters
term_words = [word for word in words if len(word)>2]
term_word_counts = Counter(term_words)

#iterate through term words counts and print the top 10
print('Top 10 Words:')
print(sorted(term_word_counts.items(), key=lambda i:i[1], reverse=True)[:10])
# Out:
# Top 10 Words:
# [('and', 69010), ('the', 42637), ('cognitive', 24256), ('with', 21544), ('for', 13569), ('cognition', 10935), ('brain', 6789), ('effects', 6607), ('study.', 5600), ('patients', 5563)]

# %% [markdown]
# ### Task 4
#
# Calculate and plot (e.g. using [plt.plot](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot)) a graph of the frequency of the 100 most frequent words in titles of papers, from most frequent to least frequent, again only counting words of three or more characters. (For readability, don't show the actual words.) Make again use of the data structures created above.

# %%
#get top hundred words
top_hunned_words = sorted(term_word_counts.items(), key=lambda i:i[1], reverse=True)[:100]
#reverse the order of the list
top_hunned_words = sorted(top_hunned_words, key=lambda i:i[1], reverse=True)

top_word_list = [x[0] for x in top_hunned_words]
top_word_count_list = [x[1] for x in top_hunned_words]



fig,ax = plt.subplots(1)
ax.plot(top_word_list, top_word_count_list)
ax.set_title('Frequency plot of most common words')
ax.set_ylabel('Count')
ax.set_xlabel('Most Common Words (decreasing in frequency)')
# Turn off X tick labels
ax.set_xticklabels([])

plt.show()

# %% [markdown]
# ### Task 5
#
# What do you notice when looking at the top 10 most frequent words? Explain all types of words we find in this top-10 and why they show up here.

# %% [markdown]
# When looking at the top 10 words (filtering out 2-letter words), I notice that top most common words are articles, prepositions, and conjunctions. It makes sense that these are commonly used words, because they are crucial for connecting complex sentence structures. These words are 'and', 'the', and 'with'.
#
# After that, I notice that words that one would typically associate with a scientific research paper about cognition. Cognitive papers are studying things that are related to the brain, so it follows that the next most common words are 'cognitive', 'cognition', and 'brain'.
#
# Furthermore, because they are research papers, there will also be many words related to scientific studies, while looking at the results. These words are 'effects', 'study.', and 'patients'. It is interesting to note that the word study has a period at the end, implying that it is most commonly used at the end of a sentence.
#
# It is also apparent in the most common words that the top few words are orders of magnitude more common than the subsequent words. For example, the word 'and' has almost 70000 occurences, but after only 5 more words it drops to around 11000 occurences with 'cognition'.

# %% [markdown]
# # Submission

# %% [markdown]
# Submit the answers to the assignment via Canvas as a modified version of this Notebook file (file with `.ipynb` extension) that includes your code and your answers.
#
# Before submitting, restart the kernel and re-run the complete code (**Kernel > Restart & Run All**), and then check whether your assignment code still works as expected.
#
# Don't forget to add your name, and remember that the assignments have to be done **individually**, and that code sharing or copying are **strictly forbidden** and will be punished.
